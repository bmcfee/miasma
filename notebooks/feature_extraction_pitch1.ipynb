# %%
import librosa
import os
import gzip
import numpy as np
from subprocess import call
import medleydb as mdb
import glob
import time

import scipy
from scipy import interpolate
print('librosa version: {:s}'.format(librosa.__version__))
print('scipy version: {:s}'.format(scipy.__version__))
print('numpy version: {:s}'.format(np.__version__))
# Out:
# librosa version: 0.5.0
# scipy version: 0.18.1
# numpy version: 1.11.3

# %%
vocalSet = set(['female singer', 'male rapper', 'male singer', 'male speaker', 'vocalists'])

# %%
# CQT Parameters
params_CQT = {
    'sr':44100, 
    'hop_length':1024, 
    'fmin':None, #Minimum frequency. Defaults to C1 ~= 32.70 Hz
    'n_bins':288, 
    'bins_per_octave':36, 
    'tuning':None, #Tuning offset in fractions of a bin (cents).
    'filter_scale':1, #Filter scale factor. Small values (<1) use shorter windows for improved time resolution.
    'norm':1, #Type of norm to use for basis function normalization.
    'sparsity':0.01, #Sparsify the CQT basis by discarding up to sparsity fraction of the energy in each basis.
    }

# %%
mdb.AUDIO_PATH
# Out:
# '/scratch/js7561/datasets/MedleyDB/Audio'

# %%
# parameters
deformer = 'pitch1'
audio_folder = '/scratch/js7561/datasets/MedleyDB_output/{:s}/audio/'.format(deformer)
output_folder = '/scratch/js7561/datasets/MedleyDB_output/{:s}/features/'.format(deformer)

compute_cqt = True
compute_activation = True

assert os.path.isdir(audio_folder)
if not os.path.isdir(output_folder):
    os.mkdir(output_folder)

# multitrack generator
trackList = os.listdir(mdb.AUDIO_PATH)
mtrack_generator = mdb.load_multitracks(trackList)

counter = 0
for track in mtrack_generator:
    
    audiofiles = glob.glob(os.path.join(audio_folder, '{:s}_*.wav'.format(track.track_id)))
    for audiofile in audiofiles:
        
        filename = os.path.basename(audiofile).replace('.wav', '')  # no extension
        print(counter, filename)
        
        cqtfolder = 'cqt{:d}_{:d}_{:d}_{:d}'.format(
            params_CQT['sr'], params_CQT['hop_length'], 
            params_CQT['n_bins']//params_CQT['bins_per_octave'],
            params_CQT['bins_per_octave'])
        if not os.path.isdir(os.path.join(output_folder, cqtfolder)):
            os.mkdir(os.path.join(output_folder, cqtfolder))
        cqtfilename = '{:s}_cqt.npy.gz'.format(filename)
        cqtfullpath = os.path.join(output_folder, cqtfolder, cqtfilename)

        actfolder = 'vocal_activation{:d}_{:d}'.format(params_CQT['sr'], params_CQT['hop_length'])
        if not os.path.isdir(os.path.join(output_folder, actfolder)):
            os.mkdir(os.path.join(output_folder, actfolder))
        actfilename = '{:s}_vocalactivation.npy.gz'.format(filename)
        actfullpath = os.path.join(output_folder, actfolder, actfilename)

        if compute_cqt:

            # load audio
            x, sr = librosa.load(audiofile, sr=params_CQT['sr'])

            # compute and save log-CQT
            logcqt = librosa.logamplitude(np.abs(librosa.cqt(y=x, **params_CQT)), ref=1.0)
            np.save(gzip.open(cqtfullpath, 'wb'), logcqt)
        else:
            # for activation only
            logcqt = np.load(gzip.open(cqtfullpath, 'rb'))

        # compute vocal activation curve (corrected version)
        if compute_activation:
            vocalIdx = ([(track.stems[k].stem_idx - 1) for k in track.stems.keys() if 
                         track.stems[k].instrument[0] in vocalSet])

            try:
                if len(vocalIdx) != 0:
                    stem_activations = np.array(track.stem_activations)[:, 1:]
                    time = np.array(track.stem_activations)[:, 0]
                    vocal_activation = np.max(stem_activations[:, vocalIdx], 1)

                    # interpolation function for vocal activation curve
                    # some issue with end point(off by a few ms) so fill with last value
                    f = interpolate.interp1d(time, vocal_activation, kind='linear',
                                             bounds_error=False, fill_value=vocal_activation[-1])

                    # vocal activation lables per frame
                    specLabel = [f(i * params_CQT['hop_length'] / params_CQT['sr']) for i in range(logcqt.shape[1])]
                    specLabel = np.array(specLabel)
                else:
                    specLabel = np.zeros(logcqt.shape[1])

                # save label
                np.save(gzip.open(actfullpath, 'wb'), specLabel)
            except IndexError as err:
                print('MISSING ACTIVATION: {:s}'.format(track.track_id))
                print(err)

    counter += 1
# Out:
# 0 MusicDelta_FreeJazz_pitch1_0
# 0 MusicDelta_FreeJazz_pitch1_1
# 0 MusicDelta_FreeJazz_pitch1_2
# 0 MusicDelta_FreeJazz_pitch1_3
# 1 TablaBreakbeatScience_CaptainSky_pitch1_2
# 1 TablaBreakbeatScience_CaptainSky_pitch1_3
# 1 TablaBreakbeatScience_CaptainSky_pitch1_0
# 1 TablaBreakbeatScience_CaptainSky_pitch1_1
# 2 TablaBreakbeatScience_PhaseTransition_pitch1_3
# 2 TablaBreakbeatScience_PhaseTransition_pitch1_1
# 2 TablaBreakbeatScience_PhaseTransition_pitch1_0
# 2 TablaBreakbeatScience_PhaseTransition_pitch1_2
# 3 MusicDelta_GriegTrolltog_pitch1_0
# 3 MusicDelta_GriegTrolltog_pitch1_1
# 3 MusicDelta_GriegTrolltog_pitch1_3
# 3 MusicDelta_GriegTrolltog_pitch1_2
# 4 CroqueMadame_Oil_pitch1_3
# 4 CroqueMadame_Oil_pitch1_1
# 4 CroqueMadame_Oil_pitch1_0
# 4 CroqueMadame_Oil_pitch1_2
# 5 TablaBreakbeatScience_RockSteady_pitch1_2
# 5 TablaBreakbeatScience_RockSteady_pitch1_3
# 5 TablaBreakbeatScience_RockSteady_pitch1_0
# 5 TablaBreakbeatScience_RockSteady_pitch1_1
# 6 KarimDouaidy_Yatora_pitch1_2
# 6 KarimDouaidy_Yatora_pitch1_1
# 6 KarimDouaidy_Yatora_pitch1_0
# 6 KarimDouaidy_Yatora_pitch1_3
# 7 TheDistricts_Vermont_pitch1_1
# 7 TheDistricts_Vermont_pitch1_0
# 7 TheDistricts_Vermont_pitch1_3
# 7 TheDistricts_Vermont_pitch1_2
# 8 MusicDelta_Vivaldi_pitch1_2
# 8 MusicDelta_Vivaldi_pitch1_1
# 8 MusicDelta_Vivaldi_pitch1_0
# 8 MusicDelta_Vivaldi_pitch1_3
# 9 MusicDelta_Rockabilly_pitch1_0
# 9 MusicDelta_Rockabilly_pitch1_1
# 9 MusicDelta_Rockabilly_pitch1_2
# 9 MusicDelta_Rockabilly_pitch1_3
# 10 AlexanderRoss_VelvetCurtain_pitch1_3
# 10 AlexanderRoss_VelvetCurtain_pitch1_1
# 10 AlexanderRoss_VelvetCurtain_pitch1_0
# 10 AlexanderRoss_VelvetCurtain_pitch1_2
# 11 HopAlong_SisterCities_pitch1_2
# 11 HopAlong_SisterCities_pitch1_1
# 11 HopAlong_SisterCities_pitch1_3
# 11 HopAlong_SisterCities_pitch1_0
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_pitch1_2
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_pitch1_3
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_pitch1_0
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_pitch1_1
# 13 MusicDelta_Country2_pitch1_2
# 13 MusicDelta_Country2_pitch1_3
# 13 MusicDelta_Country2_pitch1_1
# 13 MusicDelta_Country2_pitch1_0
# 14 MusicDelta_Rockabilly_pitch1_0
# 14 MusicDelta_Rock_pitch1_2
# 14 MusicDelta_Rock_pitch1_1
# 14 MusicDelta_Rockabilly_pitch1_1
# 14 MusicDelta_Rock_pitch1_3
# 14 MusicDelta_Rockabilly_pitch1_2
# 14 MusicDelta_Rock_pitch1_0
# 14 MusicDelta_Rockabilly_pitch1_3
# 15 MusicDelta_Beethoven_pitch1_0
# 15 MusicDelta_Beethoven_pitch1_3
# 15 MusicDelta_Beethoven_pitch1_2
# 15 MusicDelta_Beethoven_pitch1_1
# 16 MusicDelta_ModalJazz_pitch1_3
# 16 MusicDelta_ModalJazz_pitch1_0
# 16 MusicDelta_ModalJazz_pitch1_2
# 16 MusicDelta_ModalJazz_pitch1_1
# 17 AvaLuna_Waterduct_pitch1_1
# 17 AvaLuna_Waterduct_pitch1_3
# 17 AvaLuna_Waterduct_pitch1_2
# 17 AvaLuna_Waterduct_pitch1_0
# 18 MusicDelta_Zeppelin_pitch1_0
# 18 MusicDelta_Zeppelin_pitch1_2
# 18 MusicDelta_Zeppelin_pitch1_1
# 18 MusicDelta_Zeppelin_pitch1_3
# 19 MusicDelta_SpeedMetal_pitch1_2
# 19 MusicDelta_SpeedMetal_pitch1_3
# 19 MusicDelta_SpeedMetal_pitch1_1
# 19 MusicDelta_SpeedMetal_pitch1_0
# 20 MusicDelta_InTheHalloftheMountainKing_pitch1_2
# 20 MusicDelta_InTheHalloftheMountainKing_pitch1_0
# 20 MusicDelta_InTheHalloftheMountainKing_pitch1_3
# 20 MusicDelta_InTheHalloftheMountainKing_pitch1_1
# 21 Wolf_DieBekherte_pitch1_2
# 21 Wolf_DieBekherte_pitch1_1
# 21 Wolf_DieBekherte_pitch1_0
# 21 Wolf_DieBekherte_pitch1_3
# 22 MusicDelta_ChineseChaoZhou_pitch1_3
# 22 MusicDelta_ChineseChaoZhou_pitch1_0
# 22 MusicDelta_ChineseChaoZhou_pitch1_1
# 22 MusicDelta_ChineseChaoZhou_pitch1_2
# 23 Phoenix_ColliersDaughter_pitch1_2
# 23 Phoenix_ColliersDaughter_pitch1_0
# 23 Phoenix_ColliersDaughter_pitch1_1
# 23 Phoenix_ColliersDaughter_pitch1_3
# 24 ChrisJacoby_PigsFoot_pitch1_2
# 24 ChrisJacoby_PigsFoot_pitch1_3
# 24 ChrisJacoby_PigsFoot_pitch1_0
# 24 ChrisJacoby_PigsFoot_pitch1_1
# 25 MatthewEntwistle_FairerHopes_pitch1_1
# 25 MatthewEntwistle_FairerHopes_pitch1_3
# 25 MatthewEntwistle_FairerHopes_pitch1_2
# 25 MatthewEntwistle_FairerHopes_pitch1_0
# 26 TablaBreakbeatScience_Animoog_pitch1_2
# 26 TablaBreakbeatScience_Animoog_pitch1_3
# 26 TablaBreakbeatScience_Animoog_pitch1_0
# 26 TablaBreakbeatScience_Animoog_pitch1_1
# 27 Phoenix_ElzicsFarewell_pitch1_1
# 27 Phoenix_ElzicsFarewell_pitch1_3
# 27 Phoenix_ElzicsFarewell_pitch1_2
# 27 Phoenix_ElzicsFarewell_pitch1_0
# 28 MatthewEntwistle_TheArch_pitch1_0
# 28 MatthewEntwistle_TheArch_pitch1_1
# 28 MatthewEntwistle_TheArch_pitch1_3
# 28 MatthewEntwistle_TheArch_pitch1_2
# 29 KarimDouaidy_Hopscotch_pitch1_2
# 29 KarimDouaidy_Hopscotch_pitch1_0
# 29 KarimDouaidy_Hopscotch_pitch1_1
# 29 KarimDouaidy_Hopscotch_pitch1_3
# 30 LizNelson_Coldwar_pitch1_1
# 30 LizNelson_Coldwar_pitch1_2
# 30 LizNelson_Coldwar_pitch1_0
# 30 LizNelson_Coldwar_pitch1_3
# 31 MusicDelta_Hendrix_pitch1_0
# 31 MusicDelta_Hendrix_pitch1_1
# 31 MusicDelta_Hendrix_pitch1_3
# 31 MusicDelta_Hendrix_pitch1_2
# 32 MusicDelta_Country1_pitch1_0
# 32 MusicDelta_Country1_pitch1_3
# 32 MusicDelta_Country1_pitch1_1
# 32 MusicDelta_Country1_pitch1_2
# 33 AmarLal_SpringDay1_pitch1_3
# 33 AmarLal_SpringDay1_pitch1_2
# 33 AmarLal_SpringDay1_pitch1_1
# 33 AmarLal_SpringDay1_pitch1_0
# 34 MusicDelta_Beatles_pitch1_3
# 34 MusicDelta_Beatles_pitch1_1
# 34 MusicDelta_Beatles_pitch1_0
# 34 MusicDelta_Beatles_pitch1_2
# 35 Mozart_DiesBildnis_pitch1_2
# 35 Mozart_DiesBildnis_pitch1_1
# 35 Mozart_DiesBildnis_pitch1_3
# 35 Mozart_DiesBildnis_pitch1_0
# 36 ChrisJacoby_BoothShotLincoln_pitch1_1
# 36 ChrisJacoby_BoothShotLincoln_pitch1_3
# 36 ChrisJacoby_BoothShotLincoln_pitch1_2
# 36 ChrisJacoby_BoothShotLincoln_pitch1_0
# 37 MatthewEntwistle_AnEveningWithOliver_pitch1_3
# 37 MatthewEntwistle_AnEveningWithOliver_pitch1_0
# 37 MatthewEntwistle_AnEveningWithOliver_pitch1_1
# 37 MatthewEntwistle_AnEveningWithOliver_pitch1_2
# 38 Phoenix_SeanCaughlinsTheScartaglen_pitch1_2
# 38 Phoenix_SeanCaughlinsTheScartaglen_pitch1_1
# 38 Phoenix_SeanCaughlinsTheScartaglen_pitch1_0
# 38 Phoenix_SeanCaughlinsTheScartaglen_pitch1_3
# 39 AmarLal_Rest_pitch1_2
# 39 AmarLal_Rest_pitch1_0
# 39 AmarLal_Rest_pitch1_1
# 39 AmarLal_Rest_pitch1_3
# 40 InvisibleFamiliars_DisturbingWildlife_pitch1_0
# 40 InvisibleFamiliars_DisturbingWildlife_pitch1_2
# 40 InvisibleFamiliars_DisturbingWildlife_pitch1_3
# 40 InvisibleFamiliars_DisturbingWildlife_pitch1_1
# 41 MusicDelta_FunkJazz_pitch1_0
# 41 MusicDelta_FunkJazz_pitch1_1
# 41 MusicDelta_FunkJazz_pitch1_2
# 41 MusicDelta_FunkJazz_pitch1_3
# 42 TablaBreakbeatScience_MoodyPlucks_pitch1_2
# 42 TablaBreakbeatScience_MoodyPlucks_pitch1_0
# 42 TablaBreakbeatScience_MoodyPlucks_pitch1_1
# 42 TablaBreakbeatScience_MoodyPlucks_pitch1_3
# 43 MatthewEntwistle_DontYouEver_pitch1_2
# 43 MatthewEntwistle_DontYouEver_pitch1_1
# 43 MatthewEntwistle_DontYouEver_pitch1_0
# 43 MatthewEntwistle_DontYouEver_pitch1_3
# 44 Phoenix_BrokenPledgeChicagoReel_pitch1_2
# 44 Phoenix_BrokenPledgeChicagoReel_pitch1_0
# 44 Phoenix_BrokenPledgeChicagoReel_pitch1_3
# 44 Phoenix_BrokenPledgeChicagoReel_pitch1_1
# 45 MusicDelta_SwingJazz_pitch1_3
# 45 MusicDelta_SwingJazz_pitch1_1
# 45 MusicDelta_SwingJazz_pitch1_0
# 45 MusicDelta_SwingJazz_pitch1_2
# 46 TablaBreakbeatScience_WhoIsIt_pitch1_1
# 46 TablaBreakbeatScience_WhoIsIt_pitch1_2
# 46 TablaBreakbeatScience_WhoIsIt_pitch1_0
# 46 TablaBreakbeatScience_WhoIsIt_pitch1_3
# 47 NightPanther_Fire_pitch1_0
# 47 NightPanther_Fire_pitch1_3
# 47 NightPanther_Fire_pitch1_2
# 47 NightPanther_Fire_pitch1_1
# 48 ClaraBerryAndWooldog_TheBadGuys_pitch1_3
# 48 ClaraBerryAndWooldog_TheBadGuys_pitch1_1
# 48 ClaraBerryAndWooldog_TheBadGuys_pitch1_2
# 48 ClaraBerryAndWooldog_TheBadGuys_pitch1_0
# 49 MusicDelta_Punk_pitch1_1
# 49 MusicDelta_Punk_pitch1_2
# 49 MusicDelta_Punk_pitch1_0
# 49 MusicDelta_Punk_pitch1_3
# 50 PurlingHiss_Lolita_pitch1_0
# 50 PurlingHiss_Lolita_pitch1_2
# 50 PurlingHiss_Lolita_pitch1_1
# 50 PurlingHiss_Lolita_pitch1_3
# 51 HezekiahJones_BorrowedHeart_pitch1_3
# 51 HezekiahJones_BorrowedHeart_pitch1_2
# 51 HezekiahJones_BorrowedHeart_pitch1_0
# 51 HezekiahJones_BorrowedHeart_pitch1_1
# 52 MusicDelta_Britpop_pitch1_3
# 52 MusicDelta_Britpop_pitch1_0
# 52 MusicDelta_Britpop_pitch1_2
# 52 MusicDelta_Britpop_pitch1_1
# 53 Creepoid_OldTree_pitch1_1
# 53 Creepoid_OldTree_pitch1_2
# 53 Creepoid_OldTree_pitch1_3
# 53 Creepoid_OldTree_pitch1_0
# 54 TablaBreakbeatScience_MiloVsMongo_pitch1_2
# 54 TablaBreakbeatScience_MiloVsMongo_pitch1_1
# 54 TablaBreakbeatScience_MiloVsMongo_pitch1_3
# 54 TablaBreakbeatScience_MiloVsMongo_pitch1_0
# 55 TheSoSoGlos_Emergency_pitch1_0
# 55 TheSoSoGlos_Emergency_pitch1_2
# 55 TheSoSoGlos_Emergency_pitch1_1
# 55 TheSoSoGlos_Emergency_pitch1_3
# 56 ClaraBerryAndWooldog_Boys_pitch1_3
# 56 ClaraBerryAndWooldog_Boys_pitch1_2
# 56 ClaraBerryAndWooldog_Boys_pitch1_1
# 56 ClaraBerryAndWooldog_Boys_pitch1_0
# 57 Debussy_LenfantProdigue_pitch1_1
# 57 Debussy_LenfantProdigue_pitch1_0
# 57 Debussy_LenfantProdigue_pitch1_3
# 57 Debussy_LenfantProdigue_pitch1_2
# 58 AimeeNorwich_Flying_pitch1_0
# 58 AimeeNorwich_Flying_pitch1_2
# 58 AimeeNorwich_Flying_pitch1_1
# 58 AimeeNorwich_Flying_pitch1_3
# 59 TheScarletBrand_LesFleursDuMal_pitch1_3
# 59 TheScarletBrand_LesFleursDuMal_pitch1_2
# 59 TheScarletBrand_LesFleursDuMal_pitch1_1
# 59 TheScarletBrand_LesFleursDuMal_pitch1_0
# 60 MusicDelta_ChineseHenan_pitch1_3
# 60 MusicDelta_ChineseHenan_pitch1_0
# 60 MusicDelta_ChineseHenan_pitch1_2
# 60 MusicDelta_ChineseHenan_pitch1_1
# 61 MusicDelta_Grunge_pitch1_1
# 61 MusicDelta_Grunge_pitch1_2
# 61 MusicDelta_Grunge_pitch1_0
# 61 MusicDelta_Grunge_pitch1_3
# 62 JoelHelander_ExcessiveResistancetoChange_pitch1_2
# 62 JoelHelander_ExcessiveResistancetoChange_pitch1_3
# 62 JoelHelander_ExcessiveResistancetoChange_pitch1_0
# 62 JoelHelander_ExcessiveResistancetoChange_pitch1_1
# 63 MusicDelta_Reggae_pitch1_2
# 63 MusicDelta_Reggae_pitch1_1
# 63 MusicDelta_Reggae_pitch1_0
# 63 MusicDelta_Reggae_pitch1_3
# 64 AimeeNorwich_Child_pitch1_1
# 64 AimeeNorwich_Child_pitch1_0
# 64 AimeeNorwich_Child_pitch1_2
# 64 AimeeNorwich_Child_pitch1_3
# 65 Phoenix_ScotchMorris_pitch1_3
# 65 Phoenix_ScotchMorris_pitch1_2
# 65 Phoenix_ScotchMorris_pitch1_1
# 65 Phoenix_ScotchMorris_pitch1_0
# 66 EthanHein_1930sSynthAndUprightBass_pitch1_1
# 66 EthanHein_1930sSynthAndUprightBass_pitch1_2
# 66 EthanHein_1930sSynthAndUprightBass_pitch1_3
# 66 EthanHein_1930sSynthAndUprightBass_pitch1_0
# 67 MusicDelta_ChineseXinJing_pitch1_1
# 67 MusicDelta_ChineseXinJing_pitch1_3
# 67 MusicDelta_ChineseXinJing_pitch1_0
# 67 MusicDelta_ChineseXinJing_pitch1_2
# 68 Phoenix_LarkOnTheStrandDrummondCastle_pitch1_2
# 68 Phoenix_LarkOnTheStrandDrummondCastle_pitch1_3
# 68 Phoenix_LarkOnTheStrandDrummondCastle_pitch1_0
# 68 Phoenix_LarkOnTheStrandDrummondCastle_pitch1_1
# 69 StevenClark_Bounty_pitch1_0
# 69 StevenClark_Bounty_pitch1_3
# 69 StevenClark_Bounty_pitch1_2
# 69 StevenClark_Bounty_pitch1_1
# 70 EthanHein_HarmonicaFigure_pitch1_2
# 70 EthanHein_HarmonicaFigure_pitch1_1
# 70 EthanHein_HarmonicaFigure_pitch1_0
# 70 EthanHein_HarmonicaFigure_pitch1_3
# 71 AClassicEducation_NightOwl_pitch1_0
# 71 AClassicEducation_NightOwl_pitch1_1
# 71 AClassicEducation_NightOwl_pitch1_2
# 71 AClassicEducation_NightOwl_pitch1_3
# 72 MusicDelta_ChineseDrama_pitch1_1
# 72 MusicDelta_ChineseDrama_pitch1_2
# 72 MusicDelta_ChineseDrama_pitch1_0
# 72 MusicDelta_ChineseDrama_pitch1_3
# 73 MatthewEntwistle_Lontano_pitch1_2
# 73 MatthewEntwistle_Lontano_pitch1_3
# 73 MatthewEntwistle_Lontano_pitch1_0
# 73 MatthewEntwistle_Lontano_pitch1_1
# 74 Handel_TornamiAVagheggiar_pitch1_0
# 74 Handel_TornamiAVagheggiar_pitch1_3
# 74 Handel_TornamiAVagheggiar_pitch1_2
# 74 Handel_TornamiAVagheggiar_pitch1_1
# 75 MusicDelta_Shadows_pitch1_3
# 75 MusicDelta_Shadows_pitch1_0
# 75 MusicDelta_Shadows_pitch1_2
# 75 MusicDelta_Shadows_pitch1_1
# 76 EthanHein_GirlOnABridge_pitch1_0
# 76 EthanHein_GirlOnABridge_pitch1_1
# 76 EthanHein_GirlOnABridge_pitch1_2
# 76 EthanHein_GirlOnABridge_pitch1_3
# 77 MusicDelta_ChineseYaoZu_pitch1_1
# 77 MusicDelta_ChineseYaoZu_pitch1_3
# 77 MusicDelta_ChineseYaoZu_pitch1_0
# 77 MusicDelta_ChineseYaoZu_pitch1_2
# 78 MusicDelta_80sRock_pitch1_3
# 78 MusicDelta_80sRock_pitch1_2
# 78 MusicDelta_80sRock_pitch1_0
# 78 MusicDelta_80sRock_pitch1_1
# 79 HeladoNegro_MitadDelMundo_pitch1_3
# 79 HeladoNegro_MitadDelMundo_pitch1_2
# 79 HeladoNegro_MitadDelMundo_pitch1_0
# 79 HeladoNegro_MitadDelMundo_pitch1_1
# 80 Lushlife_ToynbeeSuite_pitch1_1
# 80 Lushlife_ToynbeeSuite_pitch1_3
# 80 Lushlife_ToynbeeSuite_pitch1_0
# 80 Lushlife_ToynbeeSuite_pitch1_2
# 81 MusicDelta_Disco_pitch1_3
# 81 MusicDelta_Disco_pitch1_0
# 81 MusicDelta_Disco_pitch1_2
# 81 MusicDelta_Disco_pitch1_1
# 82 Schumann_Mignon_pitch1_2
# 82 Schumann_Mignon_pitch1_1
# 82 Schumann_Mignon_pitch1_3
# 82 Schumann_Mignon_pitch1_0
# 83 ClaraBerryAndWooldog_AirTraffic_pitch1_1
# 83 ClaraBerryAndWooldog_AirTraffic_pitch1_0
# 83 ClaraBerryAndWooldog_AirTraffic_pitch1_3
# 83 ClaraBerryAndWooldog_AirTraffic_pitch1_2
# 84 Mozart_BesterJungling_pitch1_2
# 84 Mozart_BesterJungling_pitch1_1
# 84 Mozart_BesterJungling_pitch1_3
# 84 Mozart_BesterJungling_pitch1_0
# 85 SweetLights_YouLetMeDown_pitch1_2
# 85 SweetLights_YouLetMeDown_pitch1_3
# 85 SweetLights_YouLetMeDown_pitch1_0
# 85 SweetLights_YouLetMeDown_pitch1_1
# 86 StrandOfOaks_Spacestation_pitch1_2
# 86 StrandOfOaks_Spacestation_pitch1_3
# 86 StrandOfOaks_Spacestation_pitch1_0
# 86 StrandOfOaks_Spacestation_pitch1_1
# 87 MatthewEntwistle_TheFlaxenField_pitch1_2
# 87 MatthewEntwistle_TheFlaxenField_pitch1_0
# 87 MatthewEntwistle_TheFlaxenField_pitch1_1
# 87 MatthewEntwistle_TheFlaxenField_pitch1_3
# 88 Grants_PunchDrunk_pitch1_1
# 88 Grants_PunchDrunk_pitch1_3
# 88 Grants_PunchDrunk_pitch1_2
# 88 Grants_PunchDrunk_pitch1_0
# 89 JoelHelander_Definition_pitch1_3
# 89 JoelHelander_Definition_pitch1_0
# 89 JoelHelander_Definition_pitch1_1
# 89 JoelHelander_Definition_pitch1_2
# 90 BigTroubles_Phantom_pitch1_0
# 90 BigTroubles_Phantom_pitch1_2
# 90 BigTroubles_Phantom_pitch1_1
# 90 BigTroubles_Phantom_pitch1_3
# 91 ClaraBerryAndWooldog_Stella_pitch1_3
# 91 ClaraBerryAndWooldog_Stella_pitch1_2
# 91 ClaraBerryAndWooldog_Stella_pitch1_0
# 91 ClaraBerryAndWooldog_Stella_pitch1_1
# 92 DreamersOfTheGhetto_HeavyLove_pitch1_2
# 92 DreamersOfTheGhetto_HeavyLove_pitch1_0
# 92 DreamersOfTheGhetto_HeavyLove_pitch1_3
# 92 DreamersOfTheGhetto_HeavyLove_pitch1_1
# 93 MichaelKropf_AllGoodThings_pitch1_2
# 93 MichaelKropf_AllGoodThings_pitch1_0
# 93 MichaelKropf_AllGoodThings_pitch1_3
# 93 MichaelKropf_AllGoodThings_pitch1_1
# 94 Snowmine_Curfews_pitch1_2
# 94 Snowmine_Curfews_pitch1_3
# 94 Snowmine_Curfews_pitch1_0
# 94 Snowmine_Curfews_pitch1_1
# 95 CroqueMadame_Pilot_pitch1_2
# 95 CroqueMadame_Pilot_pitch1_3
# 95 CroqueMadame_Pilot_pitch1_1
# 95 CroqueMadame_Pilot_pitch1_0
# 96 JoelHelander_IntheAtticBedroom_pitch1_1
# 96 JoelHelander_IntheAtticBedroom_pitch1_3
# 96 JoelHelander_IntheAtticBedroom_pitch1_2
# 96 JoelHelander_IntheAtticBedroom_pitch1_0
# 97 EthanHein_BluesForNofi_pitch1_2
# 97 EthanHein_BluesForNofi_pitch1_3
# 97 EthanHein_BluesForNofi_pitch1_0
# 97 EthanHein_BluesForNofi_pitch1_1
# 98 MusicDelta_CoolJazz_pitch1_2
# 98 MusicDelta_CoolJazz_pitch1_3
# 98 MusicDelta_CoolJazz_pitch1_1
# 98 MusicDelta_CoolJazz_pitch1_0
# 99 Meaxic_YouListen_pitch1_0
# 99 Meaxic_YouListen_pitch1_2
# 99 Meaxic_YouListen_pitch1_3
# 99 Meaxic_YouListen_pitch1_1
# 100 Schubert_Erstarrung_pitch1_3
# 100 Schubert_Erstarrung_pitch1_0
# 100 Schubert_Erstarrung_pitch1_1
# 100 Schubert_Erstarrung_pitch1_2
# 101 FacesOnFilm_WaitingForGa_pitch1_2
# 101 FacesOnFilm_WaitingForGa_pitch1_1
# 101 FacesOnFilm_WaitingForGa_pitch1_3
# 101 FacesOnFilm_WaitingForGa_pitch1_0
# 102 SecretMountains_HighHorse_pitch1_3
# 102 SecretMountains_HighHorse_pitch1_0
# 102 SecretMountains_HighHorse_pitch1_2
# 102 SecretMountains_HighHorse_pitch1_1
# 103 MatthewEntwistle_ImpressionsOfSaturn_pitch1_1
# 103 MatthewEntwistle_ImpressionsOfSaturn_pitch1_3
# 103 MatthewEntwistle_ImpressionsOfSaturn_pitch1_2
# 103 MatthewEntwistle_ImpressionsOfSaturn_pitch1_0
# 104 MusicDelta_LatinJazz_pitch1_0
# 104 MusicDelta_LatinJazz_pitch1_3
# 104 MusicDelta_LatinJazz_pitch1_1
# 104 MusicDelta_LatinJazz_pitch1_2
# 105 TablaBreakbeatScience_Vger_pitch1_1
# 105 TablaBreakbeatScience_Vger_pitch1_0
# 105 TablaBreakbeatScience_Vger_pitch1_3
# 105 TablaBreakbeatScience_Vger_pitch1_2
# 106 BrandonWebster_YesSirICanFly_pitch1_0
# 106 BrandonWebster_YesSirICanFly_pitch1_2
# 106 BrandonWebster_YesSirICanFly_pitch1_3
# 106 BrandonWebster_YesSirICanFly_pitch1_1
# 107 CelestialShore_DieForUs_pitch1_2
# 107 CelestialShore_DieForUs_pitch1_0
# 107 CelestialShore_DieForUs_pitch1_3
# 107 CelestialShore_DieForUs_pitch1_1
# 108 BrandonWebster_DontHearAThing_pitch1_3
# 108 BrandonWebster_DontHearAThing_pitch1_1
# 108 BrandonWebster_DontHearAThing_pitch1_2
# 108 BrandonWebster_DontHearAThing_pitch1_0
# 109 FamilyBand_Again_pitch1_0
# 109 FamilyBand_Again_pitch1_2
# 109 FamilyBand_Again_pitch1_3
# 109 FamilyBand_Again_pitch1_1
# 110 MusicDelta_FusionJazz_pitch1_0
# 110 MusicDelta_FusionJazz_pitch1_3
# 110 MusicDelta_FusionJazz_pitch1_1
# 110 MusicDelta_FusionJazz_pitch1_2
# 111 PortStWillow_StayEven_pitch1_0
# 111 PortStWillow_StayEven_pitch1_1
# 111 PortStWillow_StayEven_pitch1_2
# 111 PortStWillow_StayEven_pitch1_3
# 112 Meaxic_TakeAStep_pitch1_0
# 112 Meaxic_TakeAStep_pitch1_1
# 112 Meaxic_TakeAStep_pitch1_3
# 112 Meaxic_TakeAStep_pitch1_2
# 113 MusicDelta_Pachelbel_pitch1_0
# 113 MusicDelta_Pachelbel_pitch1_1
# 113 MusicDelta_Pachelbel_pitch1_2
# 113 MusicDelta_Pachelbel_pitch1_3
# 114 MusicDelta_ChineseJiangNan_pitch1_3
# 114 MusicDelta_ChineseJiangNan_pitch1_2
# 114 MusicDelta_ChineseJiangNan_pitch1_0
# 114 MusicDelta_ChineseJiangNan_pitch1_1
# 115 MusicDelta_Gospel_pitch1_1
# 115 MusicDelta_Gospel_pitch1_3
# 115 MusicDelta_Gospel_pitch1_0
# 115 MusicDelta_Gospel_pitch1_2
# 116 TablaBreakbeatScience_Scorpio_pitch1_1
# 116 TablaBreakbeatScience_Scorpio_pitch1_3
# 116 TablaBreakbeatScience_Scorpio_pitch1_0
# 116 TablaBreakbeatScience_Scorpio_pitch1_2
# 117 AlexanderRoss_GoodbyeBolero_pitch1_1
# 117 AlexanderRoss_GoodbyeBolero_pitch1_0
# 117 AlexanderRoss_GoodbyeBolero_pitch1_2
# 117 AlexanderRoss_GoodbyeBolero_pitch1_3
# 118 MusicDelta_BebopJazz_pitch1_3
# 118 MusicDelta_BebopJazz_pitch1_2
# 118 MusicDelta_BebopJazz_pitch1_0
# 118 MusicDelta_BebopJazz_pitch1_1
# 119 LizNelson_Rainfall_pitch1_0
# 119 LizNelson_Rainfall_pitch1_3
# 119 LizNelson_Rainfall_pitch1_1
# 119 LizNelson_Rainfall_pitch1_2
# 120 Auctioneer_OurFutureFaces_pitch1_3
# 120 Auctioneer_OurFutureFaces_pitch1_1
# 120 Auctioneer_OurFutureFaces_pitch1_2
# 120 Auctioneer_OurFutureFaces_pitch1_0
# 121 LizNelson_ImComingHome_pitch1_1
# 121 LizNelson_ImComingHome_pitch1_0
# 121 LizNelson_ImComingHome_pitch1_2
# 121 LizNelson_ImComingHome_pitch1_3
