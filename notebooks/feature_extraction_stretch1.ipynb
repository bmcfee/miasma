# %%
import librosa
import os
import gzip
import numpy as np
from subprocess import call
import medleydb as mdb
import glob
import time

import scipy
from scipy import interpolate
print('librosa version: {:s}'.format(librosa.__version__))
print('scipy version: {:s}'.format(scipy.__version__))
print('numpy version: {:s}'.format(np.__version__))
# Out:
# librosa version: 0.5.0
# scipy version: 0.18.1
# numpy version: 1.11.3

# %%
vocalSet = set(['female singer', 'male rapper', 'male singer', 'male speaker', 'vocalists'])

# %%
# CQT Parameters
params_CQT = {
    'sr':44100, 
    'hop_length':1024, 
    'fmin':None, #Minimum frequency. Defaults to C1 ~= 32.70 Hz
    'n_bins':288, 
    'bins_per_octave':36, 
    'tuning':None, #Tuning offset in fractions of a bin (cents).
    'filter_scale':1, #Filter scale factor. Small values (<1) use shorter windows for improved time resolution.
    'norm':1, #Type of norm to use for basis function normalization.
    'sparsity':0.01, #Sparsify the CQT basis by discarding up to sparsity fraction of the energy in each basis.
    }

# %%
mdb.AUDIO_PATH
# Out:
# '/scratch/js7561/datasets/MedleyDB/Audio'

# %%
# parameters
deformer = 'stretch1'
audio_folder = '/scratch/js7561/datasets/MedleyDB_output/{:s}/audio/'.format(deformer)
output_folder = '/scratch/js7561/datasets/MedleyDB_output/{:s}/features/'.format(deformer)

compute_cqt = True
compute_activation = True

assert os.path.isdir(audio_folder)
if not os.path.isdir(output_folder):
    os.mkdir(output_folder)

# multitrack generator
trackList = os.listdir(mdb.AUDIO_PATH)
mtrack_generator = mdb.load_multitracks(trackList)

counter = 0
for track in mtrack_generator:
    
    audiofiles = glob.glob(os.path.join(audio_folder, '{:s}_*.wav'.format(track.track_id)))
    for audiofile in audiofiles:
        
        filename = os.path.basename(audiofile).replace('.wav', '')  # no extension
        print(counter, filename)
        
        cqtfolder = 'cqt{:d}_{:d}_{:d}_{:d}'.format(
            params_CQT['sr'], params_CQT['hop_length'], 
            params_CQT['n_bins']//params_CQT['bins_per_octave'],
            params_CQT['bins_per_octave'])
        if not os.path.isdir(os.path.join(output_folder, cqtfolder)):
            os.mkdir(os.path.join(output_folder, cqtfolder))
        cqtfilename = '{:s}_cqt.npy.gz'.format(filename)
        cqtfullpath = os.path.join(output_folder, cqtfolder, cqtfilename)

        actfolder = 'vocal_activation{:d}_{:d}'.format(params_CQT['sr'], params_CQT['hop_length'])
        if not os.path.isdir(os.path.join(output_folder, actfolder)):
            os.mkdir(os.path.join(output_folder, actfolder))
        actfilename = '{:s}_vocalactivation.npy.gz'.format(filename)
        actfullpath = os.path.join(output_folder, actfolder, actfilename)

        if compute_cqt:

            # load audio
            x, sr = librosa.load(audiofile, sr=params_CQT['sr'])

            # compute and save log-CQT
            logcqt = librosa.logamplitude(np.abs(librosa.cqt(y=x, **params_CQT)), ref=1.0)
            np.save(gzip.open(cqtfullpath, 'wb'), logcqt)
        else:
            # for activation only
            logcqt = np.load(gzip.open(cqtfullpath, 'rb'))

        # compute vocal activation curve (corrected version)
        if compute_activation:
            vocalIdx = ([(track.stems[k].stem_idx - 1) for k in track.stems.keys() if 
                         track.stems[k].instrument[0] in vocalSet])

            try:
                if len(vocalIdx) != 0:
                    stem_activations = np.array(track.stem_activations)[:, 1:]
                    time = np.array(track.stem_activations)[:, 0]
                    vocal_activation = np.max(stem_activations[:, vocalIdx], 1)

                    # interpolation function for vocal activation curve
                    # some issue with end point(off by a few ms) so fill with last value
                    f = interpolate.interp1d(time, vocal_activation, kind='linear',
                                             bounds_error=False, fill_value=vocal_activation[-1])

                    # vocal activation lables per frame
                    specLabel = [f(i * params_CQT['hop_length'] / params_CQT['sr']) for i in range(logcqt.shape[1])]
                    specLabel = np.array(specLabel)
                else:
                    specLabel = np.zeros(logcqt.shape[1])

                # save label
                np.save(gzip.open(actfullpath, 'wb'), specLabel)
            except IndexError as err:
                print('MISSING ACTIVATION: {:s}'.format(track.track_id))
                print(err)

    counter += 1
# Out:
# 0 MusicDelta_FreeJazz_stretch1_1
# 0 MusicDelta_FreeJazz_stretch1_2
# 0 MusicDelta_FreeJazz_stretch1_3
# 0 MusicDelta_FreeJazz_stretch1_0
# 1 TablaBreakbeatScience_CaptainSky_stretch1_0
# 1 TablaBreakbeatScience_CaptainSky_stretch1_1
# 1 TablaBreakbeatScience_CaptainSky_stretch1_3
# 1 TablaBreakbeatScience_CaptainSky_stretch1_2
# 2 TablaBreakbeatScience_PhaseTransition_stretch1_0
# 2 TablaBreakbeatScience_PhaseTransition_stretch1_1
# 2 TablaBreakbeatScience_PhaseTransition_stretch1_2
# 2 TablaBreakbeatScience_PhaseTransition_stretch1_3
# 3 MusicDelta_GriegTrolltog_stretch1_3
# 3 MusicDelta_GriegTrolltog_stretch1_0
# 3 MusicDelta_GriegTrolltog_stretch1_2
# 3 MusicDelta_GriegTrolltog_stretch1_1
# 4 CroqueMadame_Oil_stretch1_3
# 4 CroqueMadame_Oil_stretch1_0
# 4 CroqueMadame_Oil_stretch1_2
# 4 CroqueMadame_Oil_stretch1_1
# 5 TablaBreakbeatScience_RockSteady_stretch1_3
# 5 TablaBreakbeatScience_RockSteady_stretch1_1
# 5 TablaBreakbeatScience_RockSteady_stretch1_0
# 5 TablaBreakbeatScience_RockSteady_stretch1_2
# 6 KarimDouaidy_Yatora_stretch1_3
# 6 KarimDouaidy_Yatora_stretch1_2
# 6 KarimDouaidy_Yatora_stretch1_1
# 6 KarimDouaidy_Yatora_stretch1_0
# 7 TheDistricts_Vermont_stretch1_1
# 7 TheDistricts_Vermont_stretch1_2
# 7 TheDistricts_Vermont_stretch1_3
# 7 TheDistricts_Vermont_stretch1_0
# 8 MusicDelta_Vivaldi_stretch1_3
# 8 MusicDelta_Vivaldi_stretch1_1
# 8 MusicDelta_Vivaldi_stretch1_2
# 8 MusicDelta_Vivaldi_stretch1_0
# 9 MusicDelta_Rockabilly_stretch1_2
# 9 MusicDelta_Rockabilly_stretch1_3
# 9 MusicDelta_Rockabilly_stretch1_0
# 9 MusicDelta_Rockabilly_stretch1_1
# 10 AlexanderRoss_VelvetCurtain_stretch1_3
# 10 AlexanderRoss_VelvetCurtain_stretch1_0
# 10 AlexanderRoss_VelvetCurtain_stretch1_1
# 10 AlexanderRoss_VelvetCurtain_stretch1_2
# 11 HopAlong_SisterCities_stretch1_1
# 11 HopAlong_SisterCities_stretch1_0
# 11 HopAlong_SisterCities_stretch1_2
# 11 HopAlong_SisterCities_stretch1_3
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_stretch1_1
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_stretch1_3
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_stretch1_0
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_stretch1_2
# 13 MusicDelta_Country2_stretch1_2
# 13 MusicDelta_Country2_stretch1_1
# 13 MusicDelta_Country2_stretch1_0
# 13 MusicDelta_Country2_stretch1_3
# 14 MusicDelta_Rock_stretch1_1
# 14 MusicDelta_Rock_stretch1_2
# 14 MusicDelta_Rock_stretch1_3
# 14 MusicDelta_Rockabilly_stretch1_2
# 14 MusicDelta_Rockabilly_stretch1_3
# 14 MusicDelta_Rockabilly_stretch1_0
# 14 MusicDelta_Rockabilly_stretch1_1
# 14 MusicDelta_Rock_stretch1_0
# 15 MusicDelta_Beethoven_stretch1_2
# 15 MusicDelta_Beethoven_stretch1_3
# 15 MusicDelta_Beethoven_stretch1_1
# 15 MusicDelta_Beethoven_stretch1_0
# 16 MusicDelta_ModalJazz_stretch1_2
# 16 MusicDelta_ModalJazz_stretch1_0
# 16 MusicDelta_ModalJazz_stretch1_1
# 16 MusicDelta_ModalJazz_stretch1_3
# 17 AvaLuna_Waterduct_stretch1_0
# 17 AvaLuna_Waterduct_stretch1_2
# 17 AvaLuna_Waterduct_stretch1_1
# 17 AvaLuna_Waterduct_stretch1_3
# 18 MusicDelta_Zeppelin_stretch1_0
# 18 MusicDelta_Zeppelin_stretch1_2
# 18 MusicDelta_Zeppelin_stretch1_3
# 18 MusicDelta_Zeppelin_stretch1_1
# 19 MusicDelta_SpeedMetal_stretch1_0
# 19 MusicDelta_SpeedMetal_stretch1_2
# 19 MusicDelta_SpeedMetal_stretch1_3
# 19 MusicDelta_SpeedMetal_stretch1_1
# 20 MusicDelta_InTheHalloftheMountainKing_stretch1_1
# 20 MusicDelta_InTheHalloftheMountainKing_stretch1_0
# 20 MusicDelta_InTheHalloftheMountainKing_stretch1_3
# 20 MusicDelta_InTheHalloftheMountainKing_stretch1_2
# 21 Wolf_DieBekherte_stretch1_1
# 21 Wolf_DieBekherte_stretch1_2
# 21 Wolf_DieBekherte_stretch1_3
# 21 Wolf_DieBekherte_stretch1_0
# 22 MusicDelta_ChineseChaoZhou_stretch1_1
# 22 MusicDelta_ChineseChaoZhou_stretch1_0
# 22 MusicDelta_ChineseChaoZhou_stretch1_2
# 22 MusicDelta_ChineseChaoZhou_stretch1_3
# 23 Phoenix_ColliersDaughter_stretch1_3
# 23 Phoenix_ColliersDaughter_stretch1_0
# 23 Phoenix_ColliersDaughter_stretch1_1
# 23 Phoenix_ColliersDaughter_stretch1_2
# 24 ChrisJacoby_PigsFoot_stretch1_1
# 24 ChrisJacoby_PigsFoot_stretch1_0
# 24 ChrisJacoby_PigsFoot_stretch1_2
# 24 ChrisJacoby_PigsFoot_stretch1_3
# 25 MatthewEntwistle_FairerHopes_stretch1_0
# 25 MatthewEntwistle_FairerHopes_stretch1_2
# 25 MatthewEntwistle_FairerHopes_stretch1_1
# 25 MatthewEntwistle_FairerHopes_stretch1_3
# 26 TablaBreakbeatScience_Animoog_stretch1_0
# 26 TablaBreakbeatScience_Animoog_stretch1_2
# 26 TablaBreakbeatScience_Animoog_stretch1_3
# 26 TablaBreakbeatScience_Animoog_stretch1_1
# 27 Phoenix_ElzicsFarewell_stretch1_3
# 27 Phoenix_ElzicsFarewell_stretch1_0
# 27 Phoenix_ElzicsFarewell_stretch1_2
# 27 Phoenix_ElzicsFarewell_stretch1_1
# 28 MatthewEntwistle_TheArch_stretch1_0
# 28 MatthewEntwistle_TheArch_stretch1_1
# 28 MatthewEntwistle_TheArch_stretch1_3
# 28 MatthewEntwistle_TheArch_stretch1_2
# 29 KarimDouaidy_Hopscotch_stretch1_1
# 29 KarimDouaidy_Hopscotch_stretch1_2
# 29 KarimDouaidy_Hopscotch_stretch1_0
# 29 KarimDouaidy_Hopscotch_stretch1_3
# 30 LizNelson_Coldwar_stretch1_3
# 30 LizNelson_Coldwar_stretch1_2
# 30 LizNelson_Coldwar_stretch1_0
# 30 LizNelson_Coldwar_stretch1_1
# 31 MusicDelta_Hendrix_stretch1_2
# 31 MusicDelta_Hendrix_stretch1_1
# 31 MusicDelta_Hendrix_stretch1_0
# 31 MusicDelta_Hendrix_stretch1_3
# 32 MusicDelta_Country1_stretch1_1
# 32 MusicDelta_Country1_stretch1_2
# 32 MusicDelta_Country1_stretch1_0
# 32 MusicDelta_Country1_stretch1_3
# 33 AmarLal_SpringDay1_stretch1_3
# 33 AmarLal_SpringDay1_stretch1_0
# 33 AmarLal_SpringDay1_stretch1_1
# 33 AmarLal_SpringDay1_stretch1_2
# 34 MusicDelta_Beatles_stretch1_3
# 34 MusicDelta_Beatles_stretch1_2
# 34 MusicDelta_Beatles_stretch1_1
# 34 MusicDelta_Beatles_stretch1_0
# 35 Mozart_DiesBildnis_stretch1_3
# 35 Mozart_DiesBildnis_stretch1_1
# 35 Mozart_DiesBildnis_stretch1_0
# 35 Mozart_DiesBildnis_stretch1_2
# 36 ChrisJacoby_BoothShotLincoln_stretch1_0
# 36 ChrisJacoby_BoothShotLincoln_stretch1_2
# 36 ChrisJacoby_BoothShotLincoln_stretch1_3
# 36 ChrisJacoby_BoothShotLincoln_stretch1_1
# 37 MatthewEntwistle_AnEveningWithOliver_stretch1_2
# 37 MatthewEntwistle_AnEveningWithOliver_stretch1_3
# 37 MatthewEntwistle_AnEveningWithOliver_stretch1_0
# 37 MatthewEntwistle_AnEveningWithOliver_stretch1_1
# 38 Phoenix_SeanCaughlinsTheScartaglen_stretch1_3
# 38 Phoenix_SeanCaughlinsTheScartaglen_stretch1_1
# 38 Phoenix_SeanCaughlinsTheScartaglen_stretch1_2
# 38 Phoenix_SeanCaughlinsTheScartaglen_stretch1_0
# 39 AmarLal_Rest_stretch1_3
# 39 AmarLal_Rest_stretch1_1
# 39 AmarLal_Rest_stretch1_0
# 39 AmarLal_Rest_stretch1_2
# 40 InvisibleFamiliars_DisturbingWildlife_stretch1_1
# 40 InvisibleFamiliars_DisturbingWildlife_stretch1_2
# 40 InvisibleFamiliars_DisturbingWildlife_stretch1_0
# 40 InvisibleFamiliars_DisturbingWildlife_stretch1_3
# 41 MusicDelta_FunkJazz_stretch1_1
# 41 MusicDelta_FunkJazz_stretch1_2
# 41 MusicDelta_FunkJazz_stretch1_3
# 41 MusicDelta_FunkJazz_stretch1_0
# 42 TablaBreakbeatScience_MoodyPlucks_stretch1_1
# 42 TablaBreakbeatScience_MoodyPlucks_stretch1_0
# 42 TablaBreakbeatScience_MoodyPlucks_stretch1_3
# 42 TablaBreakbeatScience_MoodyPlucks_stretch1_2
# 43 MatthewEntwistle_DontYouEver_stretch1_0
# 43 MatthewEntwistle_DontYouEver_stretch1_1
# 43 MatthewEntwistle_DontYouEver_stretch1_3
# 43 MatthewEntwistle_DontYouEver_stretch1_2
# 44 Phoenix_BrokenPledgeChicagoReel_stretch1_0
# 44 Phoenix_BrokenPledgeChicagoReel_stretch1_2
# 44 Phoenix_BrokenPledgeChicagoReel_stretch1_3
# 44 Phoenix_BrokenPledgeChicagoReel_stretch1_1
# 45 MusicDelta_SwingJazz_stretch1_0
# 45 MusicDelta_SwingJazz_stretch1_3
# 45 MusicDelta_SwingJazz_stretch1_2
# 45 MusicDelta_SwingJazz_stretch1_1
# 46 TablaBreakbeatScience_WhoIsIt_stretch1_1
# 46 TablaBreakbeatScience_WhoIsIt_stretch1_3
# 46 TablaBreakbeatScience_WhoIsIt_stretch1_2
# 46 TablaBreakbeatScience_WhoIsIt_stretch1_0
# 47 NightPanther_Fire_stretch1_3
# 47 NightPanther_Fire_stretch1_0
# 47 NightPanther_Fire_stretch1_1
# 47 NightPanther_Fire_stretch1_2
# 48 ClaraBerryAndWooldog_TheBadGuys_stretch1_0
# 48 ClaraBerryAndWooldog_TheBadGuys_stretch1_2
# 48 ClaraBerryAndWooldog_TheBadGuys_stretch1_3
# 48 ClaraBerryAndWooldog_TheBadGuys_stretch1_1
# 49 MusicDelta_Punk_stretch1_0
# 49 MusicDelta_Punk_stretch1_3
# 49 MusicDelta_Punk_stretch1_2
# 49 MusicDelta_Punk_stretch1_1
# 50 PurlingHiss_Lolita_stretch1_1
# 50 PurlingHiss_Lolita_stretch1_0
# 50 PurlingHiss_Lolita_stretch1_3
# 50 PurlingHiss_Lolita_stretch1_2
# 51 HezekiahJones_BorrowedHeart_stretch1_1
# 51 HezekiahJones_BorrowedHeart_stretch1_0
# 51 HezekiahJones_BorrowedHeart_stretch1_3
# 51 HezekiahJones_BorrowedHeart_stretch1_2
# 52 MusicDelta_Britpop_stretch1_3
# 52 MusicDelta_Britpop_stretch1_2
# 52 MusicDelta_Britpop_stretch1_0
# 52 MusicDelta_Britpop_stretch1_1
# 53 Creepoid_OldTree_stretch1_1
# 53 Creepoid_OldTree_stretch1_0
# 53 Creepoid_OldTree_stretch1_2
# 53 Creepoid_OldTree_stretch1_3
# 54 TablaBreakbeatScience_MiloVsMongo_stretch1_2
# 54 TablaBreakbeatScience_MiloVsMongo_stretch1_3
# 54 TablaBreakbeatScience_MiloVsMongo_stretch1_0
# 54 TablaBreakbeatScience_MiloVsMongo_stretch1_1
# 55 TheSoSoGlos_Emergency_stretch1_3
# 55 TheSoSoGlos_Emergency_stretch1_1
# 55 TheSoSoGlos_Emergency_stretch1_0
# 55 TheSoSoGlos_Emergency_stretch1_2
# 56 ClaraBerryAndWooldog_Boys_stretch1_0
# 56 ClaraBerryAndWooldog_Boys_stretch1_1
# 56 ClaraBerryAndWooldog_Boys_stretch1_2
# 56 ClaraBerryAndWooldog_Boys_stretch1_3
# 57 Debussy_LenfantProdigue_stretch1_0
# 57 Debussy_LenfantProdigue_stretch1_3
# 57 Debussy_LenfantProdigue_stretch1_2
# 57 Debussy_LenfantProdigue_stretch1_1
# 58 AimeeNorwich_Flying_stretch1_3
# 58 AimeeNorwich_Flying_stretch1_0
# 58 AimeeNorwich_Flying_stretch1_2
# 58 AimeeNorwich_Flying_stretch1_1
# 59 TheScarletBrand_LesFleursDuMal_stretch1_1
# 59 TheScarletBrand_LesFleursDuMal_stretch1_0
# 59 TheScarletBrand_LesFleursDuMal_stretch1_2
# 59 TheScarletBrand_LesFleursDuMal_stretch1_3
# 60 MusicDelta_ChineseHenan_stretch1_1
# 60 MusicDelta_ChineseHenan_stretch1_3
# 60 MusicDelta_ChineseHenan_stretch1_0
# 60 MusicDelta_ChineseHenan_stretch1_2
# 61 MusicDelta_Grunge_stretch1_2
# 61 MusicDelta_Grunge_stretch1_1
# 61 MusicDelta_Grunge_stretch1_0
# 61 MusicDelta_Grunge_stretch1_3
# 62 JoelHelander_ExcessiveResistancetoChange_stretch1_1
# 62 JoelHelander_ExcessiveResistancetoChange_stretch1_0
# 62 JoelHelander_ExcessiveResistancetoChange_stretch1_2
# 62 JoelHelander_ExcessiveResistancetoChange_stretch1_3
# 63 MusicDelta_Reggae_stretch1_2
# 63 MusicDelta_Reggae_stretch1_3
# 63 MusicDelta_Reggae_stretch1_1
# 63 MusicDelta_Reggae_stretch1_0
# 64 AimeeNorwich_Child_stretch1_1
# 64 AimeeNorwich_Child_stretch1_2
# 64 AimeeNorwich_Child_stretch1_3
# 64 AimeeNorwich_Child_stretch1_0
# 65 Phoenix_ScotchMorris_stretch1_1
# 65 Phoenix_ScotchMorris_stretch1_2
# 65 Phoenix_ScotchMorris_stretch1_3
# 65 Phoenix_ScotchMorris_stretch1_0
# 66 EthanHein_1930sSynthAndUprightBass_stretch1_3
# 66 EthanHein_1930sSynthAndUprightBass_stretch1_1
# 66 EthanHein_1930sSynthAndUprightBass_stretch1_0
# 66 EthanHein_1930sSynthAndUprightBass_stretch1_2
# 67 MusicDelta_ChineseXinJing_stretch1_2
# 67 MusicDelta_ChineseXinJing_stretch1_0
# 67 MusicDelta_ChineseXinJing_stretch1_1
# 67 MusicDelta_ChineseXinJing_stretch1_3
# 68 Phoenix_LarkOnTheStrandDrummondCastle_stretch1_1
# 68 Phoenix_LarkOnTheStrandDrummondCastle_stretch1_2
# 68 Phoenix_LarkOnTheStrandDrummondCastle_stretch1_3
# 68 Phoenix_LarkOnTheStrandDrummondCastle_stretch1_0
# 69 StevenClark_Bounty_stretch1_2
# 69 StevenClark_Bounty_stretch1_0
# 69 StevenClark_Bounty_stretch1_3
# 69 StevenClark_Bounty_stretch1_1
# 70 EthanHein_HarmonicaFigure_stretch1_0
# 70 EthanHein_HarmonicaFigure_stretch1_3
# 70 EthanHein_HarmonicaFigure_stretch1_1
# 70 EthanHein_HarmonicaFigure_stretch1_2
# 71 AClassicEducation_NightOwl_stretch1_0
# 71 AClassicEducation_NightOwl_stretch1_3
# 71 AClassicEducation_NightOwl_stretch1_2
# 71 AClassicEducation_NightOwl_stretch1_1
# 72 MusicDelta_ChineseDrama_stretch1_3
# 72 MusicDelta_ChineseDrama_stretch1_1
# 72 MusicDelta_ChineseDrama_stretch1_0
# 72 MusicDelta_ChineseDrama_stretch1_2
# 73 MatthewEntwistle_Lontano_stretch1_3
# 73 MatthewEntwistle_Lontano_stretch1_2
# 73 MatthewEntwistle_Lontano_stretch1_1
# 73 MatthewEntwistle_Lontano_stretch1_0
# 74 Handel_TornamiAVagheggiar_stretch1_2
# 74 Handel_TornamiAVagheggiar_stretch1_1
# 74 Handel_TornamiAVagheggiar_stretch1_0
# 74 Handel_TornamiAVagheggiar_stretch1_3
# 75 MusicDelta_Shadows_stretch1_0
# 75 MusicDelta_Shadows_stretch1_3
# 75 MusicDelta_Shadows_stretch1_1
# 75 MusicDelta_Shadows_stretch1_2
# 76 EthanHein_GirlOnABridge_stretch1_3
# 76 EthanHein_GirlOnABridge_stretch1_2
# 76 EthanHein_GirlOnABridge_stretch1_1
# 76 EthanHein_GirlOnABridge_stretch1_0
# 77 MusicDelta_ChineseYaoZu_stretch1_2
# 77 MusicDelta_ChineseYaoZu_stretch1_3
# 77 MusicDelta_ChineseYaoZu_stretch1_1
# 77 MusicDelta_ChineseYaoZu_stretch1_0
# 78 MusicDelta_80sRock_stretch1_3
# 78 MusicDelta_80sRock_stretch1_0
# 78 MusicDelta_80sRock_stretch1_2
# 78 MusicDelta_80sRock_stretch1_1
# 79 HeladoNegro_MitadDelMundo_stretch1_0
# 79 HeladoNegro_MitadDelMundo_stretch1_3
# 79 HeladoNegro_MitadDelMundo_stretch1_2
# 79 HeladoNegro_MitadDelMundo_stretch1_1
# 80 Lushlife_ToynbeeSuite_stretch1_0
# 80 Lushlife_ToynbeeSuite_stretch1_2
# 80 Lushlife_ToynbeeSuite_stretch1_3
# 80 Lushlife_ToynbeeSuite_stretch1_1
# 81 MusicDelta_Disco_stretch1_1
# 81 MusicDelta_Disco_stretch1_2
# 81 MusicDelta_Disco_stretch1_3
# 81 MusicDelta_Disco_stretch1_0
# 82 Schumann_Mignon_stretch1_1
# 82 Schumann_Mignon_stretch1_0
# 82 Schumann_Mignon_stretch1_3
# 82 Schumann_Mignon_stretch1_2
# 83 ClaraBerryAndWooldog_AirTraffic_stretch1_3
# 83 ClaraBerryAndWooldog_AirTraffic_stretch1_2
# 83 ClaraBerryAndWooldog_AirTraffic_stretch1_1
# 83 ClaraBerryAndWooldog_AirTraffic_stretch1_0
# 84 Mozart_BesterJungling_stretch1_3
# 84 Mozart_BesterJungling_stretch1_1
# 84 Mozart_BesterJungling_stretch1_0
# 84 Mozart_BesterJungling_stretch1_2
# 85 SweetLights_YouLetMeDown_stretch1_0
# 85 SweetLights_YouLetMeDown_stretch1_2
# 85 SweetLights_YouLetMeDown_stretch1_1
# 85 SweetLights_YouLetMeDown_stretch1_3
# 86 StrandOfOaks_Spacestation_stretch1_2
# 86 StrandOfOaks_Spacestation_stretch1_3
# 86 StrandOfOaks_Spacestation_stretch1_1
# 86 StrandOfOaks_Spacestation_stretch1_0
# 87 MatthewEntwistle_TheFlaxenField_stretch1_0
# 87 MatthewEntwistle_TheFlaxenField_stretch1_1
# 87 MatthewEntwistle_TheFlaxenField_stretch1_2
# 87 MatthewEntwistle_TheFlaxenField_stretch1_3
# 88 Grants_PunchDrunk_stretch1_3
# 88 Grants_PunchDrunk_stretch1_0
# 88 Grants_PunchDrunk_stretch1_1
# 88 Grants_PunchDrunk_stretch1_2
# 89 JoelHelander_Definition_stretch1_2
# 89 JoelHelander_Definition_stretch1_3
# 89 JoelHelander_Definition_stretch1_1
# 89 JoelHelander_Definition_stretch1_0
# 90 BigTroubles_Phantom_stretch1_0
# 90 BigTroubles_Phantom_stretch1_1
# 90 BigTroubles_Phantom_stretch1_3
# 90 BigTroubles_Phantom_stretch1_2
# 91 ClaraBerryAndWooldog_Stella_stretch1_2
# 91 ClaraBerryAndWooldog_Stella_stretch1_3
# 91 ClaraBerryAndWooldog_Stella_stretch1_1
# 91 ClaraBerryAndWooldog_Stella_stretch1_0
# 92 DreamersOfTheGhetto_HeavyLove_stretch1_1
# 92 DreamersOfTheGhetto_HeavyLove_stretch1_3
# 92 DreamersOfTheGhetto_HeavyLove_stretch1_0
# 92 DreamersOfTheGhetto_HeavyLove_stretch1_2
# 93 MichaelKropf_AllGoodThings_stretch1_0
# 93 MichaelKropf_AllGoodThings_stretch1_3
# 93 MichaelKropf_AllGoodThings_stretch1_1
# 93 MichaelKropf_AllGoodThings_stretch1_2
# 94 Snowmine_Curfews_stretch1_2
# 94 Snowmine_Curfews_stretch1_1
# 94 Snowmine_Curfews_stretch1_3
# 94 Snowmine_Curfews_stretch1_0
# 95 CroqueMadame_Pilot_stretch1_1
# 95 CroqueMadame_Pilot_stretch1_0
# 95 CroqueMadame_Pilot_stretch1_3
# 95 CroqueMadame_Pilot_stretch1_2
# 96 JoelHelander_IntheAtticBedroom_stretch1_1
# 96 JoelHelander_IntheAtticBedroom_stretch1_2
# 96 JoelHelander_IntheAtticBedroom_stretch1_3
# 96 JoelHelander_IntheAtticBedroom_stretch1_0
# 97 EthanHein_BluesForNofi_stretch1_2
# 97 EthanHein_BluesForNofi_stretch1_1
# 97 EthanHein_BluesForNofi_stretch1_0
# 97 EthanHein_BluesForNofi_stretch1_3
# 98 MusicDelta_CoolJazz_stretch1_2
# 98 MusicDelta_CoolJazz_stretch1_1
# 98 MusicDelta_CoolJazz_stretch1_3
# 98 MusicDelta_CoolJazz_stretch1_0
# 99 Meaxic_YouListen_stretch1_1
# 99 Meaxic_YouListen_stretch1_0
# 99 Meaxic_YouListen_stretch1_3
# 99 Meaxic_YouListen_stretch1_2
# 100 Schubert_Erstarrung_stretch1_2
# 100 Schubert_Erstarrung_stretch1_1
# 100 Schubert_Erstarrung_stretch1_0
# 100 Schubert_Erstarrung_stretch1_3
# 101 FacesOnFilm_WaitingForGa_stretch1_2
# 101 FacesOnFilm_WaitingForGa_stretch1_3
# 101 FacesOnFilm_WaitingForGa_stretch1_0
# 101 FacesOnFilm_WaitingForGa_stretch1_1
# 102 SecretMountains_HighHorse_stretch1_0
# 102 SecretMountains_HighHorse_stretch1_3
# 102 SecretMountains_HighHorse_stretch1_2
# 102 SecretMountains_HighHorse_stretch1_1
# 103 MatthewEntwistle_ImpressionsOfSaturn_stretch1_0
# 103 MatthewEntwistle_ImpressionsOfSaturn_stretch1_3
# 103 MatthewEntwistle_ImpressionsOfSaturn_stretch1_1
# 103 MatthewEntwistle_ImpressionsOfSaturn_stretch1_2
# 104 MusicDelta_LatinJazz_stretch1_3
# 104 MusicDelta_LatinJazz_stretch1_2
# 104 MusicDelta_LatinJazz_stretch1_1
# 104 MusicDelta_LatinJazz_stretch1_0
# 105 TablaBreakbeatScience_Vger_stretch1_2
# 105 TablaBreakbeatScience_Vger_stretch1_3
# 105 TablaBreakbeatScience_Vger_stretch1_1
# 105 TablaBreakbeatScience_Vger_stretch1_0
# 106 BrandonWebster_YesSirICanFly_stretch1_1
# 106 BrandonWebster_YesSirICanFly_stretch1_0
# 106 BrandonWebster_YesSirICanFly_stretch1_3
# 106 BrandonWebster_YesSirICanFly_stretch1_2
# 107 CelestialShore_DieForUs_stretch1_1
# 107 CelestialShore_DieForUs_stretch1_2
# 107 CelestialShore_DieForUs_stretch1_3
# 107 CelestialShore_DieForUs_stretch1_0
# 108 BrandonWebster_DontHearAThing_stretch1_3
# 108 BrandonWebster_DontHearAThing_stretch1_1
# 108 BrandonWebster_DontHearAThing_stretch1_2
# 108 BrandonWebster_DontHearAThing_stretch1_0
# 109 FamilyBand_Again_stretch1_3
# 109 FamilyBand_Again_stretch1_0
# 109 FamilyBand_Again_stretch1_2
# 109 FamilyBand_Again_stretch1_1
# 110 MusicDelta_FusionJazz_stretch1_2
# 110 MusicDelta_FusionJazz_stretch1_1
# 110 MusicDelta_FusionJazz_stretch1_3
# 110 MusicDelta_FusionJazz_stretch1_0
# 111 PortStWillow_StayEven_stretch1_1
# 111 PortStWillow_StayEven_stretch1_0
# 111 PortStWillow_StayEven_stretch1_2
# 111 PortStWillow_StayEven_stretch1_3
# 112 Meaxic_TakeAStep_stretch1_1
# 112 Meaxic_TakeAStep_stretch1_0
# 112 Meaxic_TakeAStep_stretch1_3
# 112 Meaxic_TakeAStep_stretch1_2
# 113 MusicDelta_Pachelbel_stretch1_2
# 113 MusicDelta_Pachelbel_stretch1_0
# 113 MusicDelta_Pachelbel_stretch1_3
# 113 MusicDelta_Pachelbel_stretch1_1
# 114 MusicDelta_ChineseJiangNan_stretch1_1
# 114 MusicDelta_ChineseJiangNan_stretch1_0
# 114 MusicDelta_ChineseJiangNan_stretch1_2
# 114 MusicDelta_ChineseJiangNan_stretch1_3
# 115 MusicDelta_Gospel_stretch1_2
# 115 MusicDelta_Gospel_stretch1_3
# 115 MusicDelta_Gospel_stretch1_0
# 115 MusicDelta_Gospel_stretch1_1
# 116 TablaBreakbeatScience_Scorpio_stretch1_1
# 116 TablaBreakbeatScience_Scorpio_stretch1_0
# 116 TablaBreakbeatScience_Scorpio_stretch1_3
# 116 TablaBreakbeatScience_Scorpio_stretch1_2
# 117 AlexanderRoss_GoodbyeBolero_stretch1_3
# 117 AlexanderRoss_GoodbyeBolero_stretch1_2
# 117 AlexanderRoss_GoodbyeBolero_stretch1_1
# 117 AlexanderRoss_GoodbyeBolero_stretch1_0
# 118 MusicDelta_BebopJazz_stretch1_2
# 118 MusicDelta_BebopJazz_stretch1_1
# 118 MusicDelta_BebopJazz_stretch1_3
# 118 MusicDelta_BebopJazz_stretch1_0
# 119 LizNelson_Rainfall_stretch1_3
# 119 LizNelson_Rainfall_stretch1_2
# 119 LizNelson_Rainfall_stretch1_0
# 119 LizNelson_Rainfall_stretch1_1
# 120 Auctioneer_OurFutureFaces_stretch1_2
# 120 Auctioneer_OurFutureFaces_stretch1_1
# 120 Auctioneer_OurFutureFaces_stretch1_0
# 120 Auctioneer_OurFutureFaces_stretch1_3
# 121 LizNelson_ImComingHome_stretch1_2
# 121 LizNelson_ImComingHome_stretch1_3
# 121 LizNelson_ImComingHome_stretch1_1
# 121 LizNelson_ImComingHome_stretch1_0
