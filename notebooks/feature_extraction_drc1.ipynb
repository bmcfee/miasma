# %%
import librosa
import os
import gzip
import numpy as np
from subprocess import call
import medleydb as mdb
import glob
import time

import scipy
from scipy import interpolate
print('librosa version: {:s}'.format(librosa.__version__))
print('scipy version: {:s}'.format(scipy.__version__))
print('numpy version: {:s}'.format(np.__version__))
# Out:
# librosa version: 0.5.0
# scipy version: 0.18.1
# numpy version: 1.11.3

# %%
vocalSet = set(['female singer', 'male rapper', 'male singer', 'male speaker', 'vocalists'])

# %%
# CQT Parameters
params_CQT = {
    'sr':44100, 
    'hop_length':1024, 
    'fmin':None, #Minimum frequency. Defaults to C1 ~= 32.70 Hz
    'n_bins':288, 
    'bins_per_octave':36, 
    'tuning':None, #Tuning offset in fractions of a bin (cents).
    'filter_scale':1, #Filter scale factor. Small values (<1) use shorter windows for improved time resolution.
    'norm':1, #Type of norm to use for basis function normalization.
    'sparsity':0.01, #Sparsify the CQT basis by discarding up to sparsity fraction of the energy in each basis.
    }

# %%
mdb.AUDIO_PATH
# Out:
# '/scratch/js7561/datasets/MedleyDB/Audio'

# %%
# parameters
deformer = 'drc1'
audio_folder = '/scratch/js7561/datasets/MedleyDB_output/{:s}/audio/'.format(deformer)
output_folder = '/scratch/js7561/datasets/MedleyDB_output/{:s}/features/'.format(deformer)

compute_cqt = True
compute_activation = True

assert os.path.isdir(audio_folder)
if not os.path.isdir(output_folder):
    os.mkdir(output_folder)

# multitrack generator
trackList = os.listdir(mdb.AUDIO_PATH)
mtrack_generator = mdb.load_multitracks(trackList)

counter = 0
for track in mtrack_generator:
    
    audiofiles = glob.glob(os.path.join(audio_folder, '{:s}*.wav'.format(track.track_id)))
    for audiofile in audiofiles:
        
        filename = os.path.basename(audiofile).replace('.wav', '')  # no extension
        print(counter, filename)
        
        cqtfolder = 'cqt{:d}_{:d}_{:d}_{:d}'.format(
            params_CQT['sr'], params_CQT['hop_length'], 
            params_CQT['n_bins']//params_CQT['bins_per_octave'],
            params_CQT['bins_per_octave'])
        if not os.path.isdir(os.path.join(output_folder, cqtfolder)):
            os.mkdir(os.path.join(output_folder, cqtfolder))
        cqtfilename = '{:s}_cqt.npy.gz'.format(filename)
        cqtfullpath = os.path.join(output_folder, cqtfolder, cqtfilename)

        actfolder = 'vocal_activation{:d}_{:d}'.format(params_CQT['sr'], params_CQT['hop_length'])
        if not os.path.isdir(os.path.join(output_folder, actfolder)):
            os.mkdir(os.path.join(output_folder, actfolder))
        actfilename = '{:s}_vocalactivation.npy.gz'.format(filename)
        actfullpath = os.path.join(output_folder, actfolder, actfilename)

        if compute_cqt:

            # load audio
            x, sr = librosa.load(audiofile, sr=params_CQT['sr'])

            # compute and save log-CQT
            logcqt = librosa.logamplitude(np.abs(librosa.cqt(y=x, **params_CQT)), ref=1.0)
            np.save(gzip.open(cqtfullpath, 'wb'), logcqt)
        else:
            # for activation only
            logcqt = np.load(gzip.open(cqtfullpath, 'rb'))

        # compute vocal activation curve (corrected version)
        if compute_activation:
            vocalIdx = ([(track.stems[k].stem_idx - 1) for k in track.stems.keys() if 
                         track.stems[k].instrument[0] in vocalSet])

            try:
                if len(vocalIdx) != 0:
                    stem_activations = np.array(track.stem_activations)[:, 1:]
                    time = np.array(track.stem_activations)[:, 0]
                    vocal_activation = np.max(stem_activations[:, vocalIdx], 1)

                    # interpolation function for vocal activation curve
                    # some issue with end point(off by a few ms) so fill with last value
                    f = interpolate.interp1d(time, vocal_activation, kind='linear',
                                             bounds_error=False, fill_value=vocal_activation[-1])

                    # vocal activation lables per frame
                    specLabel = [f(i * params_CQT['hop_length'] / params_CQT['sr']) for i in range(logcqt.shape[1])]
                    specLabel = np.array(specLabel)
                else:
                    specLabel = np.zeros(logcqt.shape[1])

                # save label
                np.save(gzip.open(actfullpath, 'wb'), specLabel)
            except IndexError as err:
                print('MISSING ACTIVATION: {:s}'.format(track.track_id))
                print(err)

    counter += 1
# Out:
# 0 MusicDelta_FreeJazz_drc1_1
# 0 MusicDelta_FreeJazz_drc1_0
# 0 MusicDelta_FreeJazz_drc1_3
# 0 MusicDelta_FreeJazz_drc1_2
# 1 TablaBreakbeatScience_CaptainSky_drc1_3
# 1 TablaBreakbeatScience_CaptainSky_drc1_1
# 1 TablaBreakbeatScience_CaptainSky_drc1_0
# 1 TablaBreakbeatScience_CaptainSky_drc1_2
# 2 TablaBreakbeatScience_PhaseTransition_drc1_2
# 2 TablaBreakbeatScience_PhaseTransition_drc1_0
# 2 TablaBreakbeatScience_PhaseTransition_drc1_3
# 2 TablaBreakbeatScience_PhaseTransition_drc1_1
# 3 MusicDelta_GriegTrolltog_drc1_1
# 3 MusicDelta_GriegTrolltog_drc1_0
# 3 MusicDelta_GriegTrolltog_drc1_3
# 3 MusicDelta_GriegTrolltog_drc1_2
# 4 CroqueMadame_Oil_drc1_1
# 4 CroqueMadame_Oil_drc1_2
# 4 CroqueMadame_Oil_drc1_3
# 4 CroqueMadame_Oil_drc1_0
# 5 TablaBreakbeatScience_RockSteady_drc1_2
# 5 TablaBreakbeatScience_RockSteady_drc1_0
# 5 TablaBreakbeatScience_RockSteady_drc1_1
# 5 TablaBreakbeatScience_RockSteady_drc1_3
# 6 KarimDouaidy_Yatora_drc1_2
# 6 KarimDouaidy_Yatora_drc1_1
# 6 KarimDouaidy_Yatora_drc1_0
# 6 KarimDouaidy_Yatora_drc1_3
# 7 TheDistricts_Vermont_drc1_2
# 7 TheDistricts_Vermont_drc1_0
# 7 TheDistricts_Vermont_drc1_3
# 7 TheDistricts_Vermont_drc1_1
# 8 MusicDelta_Vivaldi_drc1_1
# 8 MusicDelta_Vivaldi_drc1_0
# 8 MusicDelta_Vivaldi_drc1_2
# 8 MusicDelta_Vivaldi_drc1_3
# 9 MusicDelta_Rockabilly_drc1_0
# 9 MusicDelta_Rockabilly_drc1_1
# 9 MusicDelta_Rockabilly_drc1_2
# 9 MusicDelta_Rockabilly_drc1_3
# 10 AlexanderRoss_VelvetCurtain_drc1_2
# 10 AlexanderRoss_VelvetCurtain_drc1_0
# 10 AlexanderRoss_VelvetCurtain_drc1_3
# 10 AlexanderRoss_VelvetCurtain_drc1_1
# 11 HopAlong_SisterCities_drc1_0
# 11 HopAlong_SisterCities_drc1_2
# 11 HopAlong_SisterCities_drc1_3
# 11 HopAlong_SisterCities_drc1_1
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_drc1_0
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_drc1_3
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_drc1_1
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_drc1_2
# 13 MusicDelta_Country2_drc1_2
# 13 MusicDelta_Country2_drc1_3
# 13 MusicDelta_Country2_drc1_0
# 13 MusicDelta_Country2_drc1_1
# 14 MusicDelta_Rockabilly_drc1_0
# 14 MusicDelta_Rock_drc1_2
# 14 MusicDelta_Rockabilly_drc1_1
# 14 MusicDelta_Rock_drc1_3
# 14 MusicDelta_Rock_drc1_1
# 14 MusicDelta_Rockabilly_drc1_2
# 14 MusicDelta_Rockabilly_drc1_3
# 14 MusicDelta_Rock_drc1_0
# 15 MusicDelta_Beethoven_drc1_0
# 15 MusicDelta_Beethoven_drc1_2
# 15 MusicDelta_Beethoven_drc1_3
# 15 MusicDelta_Beethoven_drc1_1
# 16 MusicDelta_ModalJazz_drc1_3
# 16 MusicDelta_ModalJazz_drc1_1
# 16 MusicDelta_ModalJazz_drc1_2
# 16 MusicDelta_ModalJazz_drc1_0
# 17 AvaLuna_Waterduct_drc1_2
# 17 AvaLuna_Waterduct_drc1_3
# 17 AvaLuna_Waterduct_drc1_0
# 17 AvaLuna_Waterduct_drc1_1
# 18 MusicDelta_Zeppelin_drc1_2
# 18 MusicDelta_Zeppelin_drc1_1
# 18 MusicDelta_Zeppelin_drc1_3
# 18 MusicDelta_Zeppelin_drc1_0
# 19 MusicDelta_SpeedMetal_drc1_3
# 19 MusicDelta_SpeedMetal_drc1_0
# 19 MusicDelta_SpeedMetal_drc1_2
# 19 MusicDelta_SpeedMetal_drc1_1
# 20 MusicDelta_InTheHalloftheMountainKing_drc1_2
# 20 MusicDelta_InTheHalloftheMountainKing_drc1_0
# 20 MusicDelta_InTheHalloftheMountainKing_drc1_1
# 20 MusicDelta_InTheHalloftheMountainKing_drc1_3
# 21 Wolf_DieBekherte_drc1_3
# 21 Wolf_DieBekherte_drc1_2
# 21 Wolf_DieBekherte_drc1_1
# 21 Wolf_DieBekherte_drc1_0
# 22 MusicDelta_ChineseChaoZhou_drc1_1
# 22 MusicDelta_ChineseChaoZhou_drc1_3
# 22 MusicDelta_ChineseChaoZhou_drc1_2
# 22 MusicDelta_ChineseChaoZhou_drc1_0
# 23 Phoenix_ColliersDaughter_drc1_2
# 23 Phoenix_ColliersDaughter_drc1_3
# 23 Phoenix_ColliersDaughter_drc1_0
# 23 Phoenix_ColliersDaughter_drc1_1
# 24 ChrisJacoby_PigsFoot_drc1_2
# 24 ChrisJacoby_PigsFoot_drc1_1
# 24 ChrisJacoby_PigsFoot_drc1_3
# 24 ChrisJacoby_PigsFoot_drc1_0
# 25 MatthewEntwistle_FairerHopes_drc1_3
# 25 MatthewEntwistle_FairerHopes_drc1_0
# 25 MatthewEntwistle_FairerHopes_drc1_1
# 25 MatthewEntwistle_FairerHopes_drc1_2
# 26 TablaBreakbeatScience_Animoog_drc1_2
# 26 TablaBreakbeatScience_Animoog_drc1_1
# 26 TablaBreakbeatScience_Animoog_drc1_0
# 26 TablaBreakbeatScience_Animoog_drc1_3
# 27 Phoenix_ElzicsFarewell_drc1_1
# 27 Phoenix_ElzicsFarewell_drc1_0
# 27 Phoenix_ElzicsFarewell_drc1_2
# 27 Phoenix_ElzicsFarewell_drc1_3
# 28 MatthewEntwistle_TheArch_drc1_0
# 28 MatthewEntwistle_TheArch_drc1_1
# 28 MatthewEntwistle_TheArch_drc1_2
# 28 MatthewEntwistle_TheArch_drc1_3
# 29 KarimDouaidy_Hopscotch_drc1_3
# 29 KarimDouaidy_Hopscotch_drc1_1
# 29 KarimDouaidy_Hopscotch_drc1_2
# 29 KarimDouaidy_Hopscotch_drc1_0
# 30 LizNelson_Coldwar_drc1_0
# 30 LizNelson_Coldwar_drc1_3
# 30 LizNelson_Coldwar_drc1_2
# 30 LizNelson_Coldwar_drc1_1
# 31 MusicDelta_Hendrix_drc1_2
# 31 MusicDelta_Hendrix_drc1_1
# 31 MusicDelta_Hendrix_drc1_0
# 31 MusicDelta_Hendrix_drc1_3
# 32 MusicDelta_Country1_drc1_3
# 32 MusicDelta_Country1_drc1_1
# 32 MusicDelta_Country1_drc1_2
# 32 MusicDelta_Country1_drc1_0
# 33 AmarLal_SpringDay1_drc1_2
# 33 AmarLal_SpringDay1_drc1_0
# 33 AmarLal_SpringDay1_drc1_3
# 33 AmarLal_SpringDay1_drc1_1
# 34 MusicDelta_Beatles_drc1_2
# 34 MusicDelta_Beatles_drc1_0
# 34 MusicDelta_Beatles_drc1_1
# 34 MusicDelta_Beatles_drc1_3
# 35 Mozart_DiesBildnis_drc1_3
# 35 Mozart_DiesBildnis_drc1_2
# 35 Mozart_DiesBildnis_drc1_0
# 35 Mozart_DiesBildnis_drc1_1
# 36 ChrisJacoby_BoothShotLincoln_drc1_1
# 36 ChrisJacoby_BoothShotLincoln_drc1_2
# 36 ChrisJacoby_BoothShotLincoln_drc1_0
# 36 ChrisJacoby_BoothShotLincoln_drc1_3
# 37 MatthewEntwistle_AnEveningWithOliver_drc1_3
# 37 MatthewEntwistle_AnEveningWithOliver_drc1_2
# 37 MatthewEntwistle_AnEveningWithOliver_drc1_0
# 37 MatthewEntwistle_AnEveningWithOliver_drc1_1
# 38 Phoenix_SeanCaughlinsTheScartaglen_drc1_3
# 38 Phoenix_SeanCaughlinsTheScartaglen_drc1_2
# 38 Phoenix_SeanCaughlinsTheScartaglen_drc1_0
# 38 Phoenix_SeanCaughlinsTheScartaglen_drc1_1
# 39 AmarLal_Rest_drc1_0
# 39 AmarLal_Rest_drc1_1
# 39 AmarLal_Rest_drc1_3
# 39 AmarLal_Rest_drc1_2
# 40 InvisibleFamiliars_DisturbingWildlife_drc1_3
# 40 InvisibleFamiliars_DisturbingWildlife_drc1_2
# 40 InvisibleFamiliars_DisturbingWildlife_drc1_1
# 40 InvisibleFamiliars_DisturbingWildlife_drc1_0
# 41 MusicDelta_FunkJazz_drc1_3
# 41 MusicDelta_FunkJazz_drc1_0
# 41 MusicDelta_FunkJazz_drc1_1
# 41 MusicDelta_FunkJazz_drc1_2
# 42 TablaBreakbeatScience_MoodyPlucks_drc1_2
# 42 TablaBreakbeatScience_MoodyPlucks_drc1_3
# 42 TablaBreakbeatScience_MoodyPlucks_drc1_1
# 42 TablaBreakbeatScience_MoodyPlucks_drc1_0
# 43 MatthewEntwistle_DontYouEver_drc1_2
# 43 MatthewEntwistle_DontYouEver_drc1_1
# 43 MatthewEntwistle_DontYouEver_drc1_3
# 43 MatthewEntwistle_DontYouEver_drc1_0
# 44 Phoenix_BrokenPledgeChicagoReel_drc1_3
# 44 Phoenix_BrokenPledgeChicagoReel_drc1_2
# 44 Phoenix_BrokenPledgeChicagoReel_drc1_0
# 44 Phoenix_BrokenPledgeChicagoReel_drc1_1
# 45 MusicDelta_SwingJazz_drc1_0
# 45 MusicDelta_SwingJazz_drc1_1
# 45 MusicDelta_SwingJazz_drc1_3
# 45 MusicDelta_SwingJazz_drc1_2
# 46 TablaBreakbeatScience_WhoIsIt_drc1_1
# 46 TablaBreakbeatScience_WhoIsIt_drc1_0
# 46 TablaBreakbeatScience_WhoIsIt_drc1_3
# 46 TablaBreakbeatScience_WhoIsIt_drc1_2
# 47 NightPanther_Fire_drc1_2
# 47 NightPanther_Fire_drc1_0
# 47 NightPanther_Fire_drc1_3
# 47 NightPanther_Fire_drc1_1
# 48 ClaraBerryAndWooldog_TheBadGuys_drc1_3
# 48 ClaraBerryAndWooldog_TheBadGuys_drc1_2
# 48 ClaraBerryAndWooldog_TheBadGuys_drc1_0
# 48 ClaraBerryAndWooldog_TheBadGuys_drc1_1
# 49 MusicDelta_Punk_drc1_2
# 49 MusicDelta_Punk_drc1_3
# 49 MusicDelta_Punk_drc1_1
# 49 MusicDelta_Punk_drc1_0
# 50 PurlingHiss_Lolita_drc1_1
# 50 PurlingHiss_Lolita_drc1_2
# 50 PurlingHiss_Lolita_drc1_3
# 50 PurlingHiss_Lolita_drc1_0
# 51 HezekiahJones_BorrowedHeart_drc1_2
# 51 HezekiahJones_BorrowedHeart_drc1_3
# 51 HezekiahJones_BorrowedHeart_drc1_1
# 51 HezekiahJones_BorrowedHeart_drc1_0
# 52 MusicDelta_Britpop_drc1_0
# 52 MusicDelta_Britpop_drc1_1
# 52 MusicDelta_Britpop_drc1_2
# 52 MusicDelta_Britpop_drc1_3
# 53 Creepoid_OldTree_drc1_1
# 53 Creepoid_OldTree_drc1_2
# 53 Creepoid_OldTree_drc1_3
# 53 Creepoid_OldTree_drc1_0
# 54 TablaBreakbeatScience_MiloVsMongo_drc1_1
# 54 TablaBreakbeatScience_MiloVsMongo_drc1_0
# 54 TablaBreakbeatScience_MiloVsMongo_drc1_2
# 54 TablaBreakbeatScience_MiloVsMongo_drc1_3
# 55 TheSoSoGlos_Emergency_drc1_3
# 55 TheSoSoGlos_Emergency_drc1_1
# 55 TheSoSoGlos_Emergency_drc1_0
# 55 TheSoSoGlos_Emergency_drc1_2
# 56 ClaraBerryAndWooldog_Boys_drc1_1
# 56 ClaraBerryAndWooldog_Boys_drc1_2
# 56 ClaraBerryAndWooldog_Boys_drc1_0
# 56 ClaraBerryAndWooldog_Boys_drc1_3
# 57 Debussy_LenfantProdigue_drc1_0
# 57 Debussy_LenfantProdigue_drc1_2
# 57 Debussy_LenfantProdigue_drc1_3
# 57 Debussy_LenfantProdigue_drc1_1
# 58 AimeeNorwich_Flying_drc1_2
# 58 AimeeNorwich_Flying_drc1_1
# 58 AimeeNorwich_Flying_drc1_3
# 58 AimeeNorwich_Flying_drc1_0
# 59 TheScarletBrand_LesFleursDuMal_drc1_3
# 59 TheScarletBrand_LesFleursDuMal_drc1_1
# 59 TheScarletBrand_LesFleursDuMal_drc1_0
# 59 TheScarletBrand_LesFleursDuMal_drc1_2
# 60 MusicDelta_ChineseHenan_drc1_0
# 60 MusicDelta_ChineseHenan_drc1_3
# 60 MusicDelta_ChineseHenan_drc1_1
# 60 MusicDelta_ChineseHenan_drc1_2
# 61 MusicDelta_Grunge_drc1_1
# 61 MusicDelta_Grunge_drc1_2
# 61 MusicDelta_Grunge_drc1_3
# 61 MusicDelta_Grunge_drc1_0
# 62 JoelHelander_ExcessiveResistancetoChange_drc1_0
# 62 JoelHelander_ExcessiveResistancetoChange_drc1_3
# 62 JoelHelander_ExcessiveResistancetoChange_drc1_2
# 62 JoelHelander_ExcessiveResistancetoChange_drc1_1
# 63 MusicDelta_Reggae_drc1_3
# 63 MusicDelta_Reggae_drc1_0
# 63 MusicDelta_Reggae_drc1_1
# 63 MusicDelta_Reggae_drc1_2
# 64 AimeeNorwich_Child_drc1_1
# 64 AimeeNorwich_Child_drc1_2
# 64 AimeeNorwich_Child_drc1_3
# 64 AimeeNorwich_Child_drc1_0
# 65 Phoenix_ScotchMorris_drc1_2
# 65 Phoenix_ScotchMorris_drc1_0
# 65 Phoenix_ScotchMorris_drc1_1
# 65 Phoenix_ScotchMorris_drc1_3
# 66 EthanHein_1930sSynthAndUprightBass_drc1_0
# 66 EthanHein_1930sSynthAndUprightBass_drc1_1
# 66 EthanHein_1930sSynthAndUprightBass_drc1_3
# 66 EthanHein_1930sSynthAndUprightBass_drc1_2
# 67 MusicDelta_ChineseXinJing_drc1_2
# 67 MusicDelta_ChineseXinJing_drc1_1
# 67 MusicDelta_ChineseXinJing_drc1_0
# 67 MusicDelta_ChineseXinJing_drc1_3
# 68 Phoenix_LarkOnTheStrandDrummondCastle_drc1_3
# 68 Phoenix_LarkOnTheStrandDrummondCastle_drc1_2
# 68 Phoenix_LarkOnTheStrandDrummondCastle_drc1_0
# 68 Phoenix_LarkOnTheStrandDrummondCastle_drc1_1
# 69 StevenClark_Bounty_drc1_1
# 69 StevenClark_Bounty_drc1_2
# 69 StevenClark_Bounty_drc1_3
# 69 StevenClark_Bounty_drc1_0
# 70 EthanHein_HarmonicaFigure_drc1_2
# 70 EthanHein_HarmonicaFigure_drc1_3
# 70 EthanHein_HarmonicaFigure_drc1_0
# 70 EthanHein_HarmonicaFigure_drc1_1
# 71 AClassicEducation_NightOwl_drc1_0
# 71 AClassicEducation_NightOwl_drc1_1
# 71 AClassicEducation_NightOwl_drc1_2
# 71 AClassicEducation_NightOwl_drc1_3
# 72 MusicDelta_ChineseDrama_drc1_3
# 72 MusicDelta_ChineseDrama_drc1_2
# 72 MusicDelta_ChineseDrama_drc1_0
# 72 MusicDelta_ChineseDrama_drc1_1
# 73 MatthewEntwistle_Lontano_drc1_2
# 73 MatthewEntwistle_Lontano_drc1_1
# 73 MatthewEntwistle_Lontano_drc1_3
# 73 MatthewEntwistle_Lontano_drc1_0
# 74 Handel_TornamiAVagheggiar_drc1_1
# 74 Handel_TornamiAVagheggiar_drc1_0
# 74 Handel_TornamiAVagheggiar_drc1_3
# 74 Handel_TornamiAVagheggiar_drc1_2
# 75 MusicDelta_Shadows_drc1_2
# 75 MusicDelta_Shadows_drc1_1
# 75 MusicDelta_Shadows_drc1_0
# 75 MusicDelta_Shadows_drc1_3
# 76 EthanHein_GirlOnABridge_drc1_2
# 76 EthanHein_GirlOnABridge_drc1_0
# 76 EthanHein_GirlOnABridge_drc1_1
# 76 EthanHein_GirlOnABridge_drc1_3
# 77 MusicDelta_ChineseYaoZu_drc1_0
# 77 MusicDelta_ChineseYaoZu_drc1_1
# 77 MusicDelta_ChineseYaoZu_drc1_3
# 77 MusicDelta_ChineseYaoZu_drc1_2
# 78 MusicDelta_80sRock_drc1_3
# 78 MusicDelta_80sRock_drc1_0
# 78 MusicDelta_80sRock_drc1_2
# 78 MusicDelta_80sRock_drc1_1
# 79 HeladoNegro_MitadDelMundo_drc1_1
# 79 HeladoNegro_MitadDelMundo_drc1_3
# 79 HeladoNegro_MitadDelMundo_drc1_2
# 79 HeladoNegro_MitadDelMundo_drc1_0
# 80 Lushlife_ToynbeeSuite_drc1_3
# 80 Lushlife_ToynbeeSuite_drc1_2
# 80 Lushlife_ToynbeeSuite_drc1_1
# 80 Lushlife_ToynbeeSuite_drc1_0
# 81 MusicDelta_Disco_drc1_3
# 81 MusicDelta_Disco_drc1_1
# 81 MusicDelta_Disco_drc1_2
# 81 MusicDelta_Disco_drc1_0
# 82 Schumann_Mignon_drc1_0
# 82 Schumann_Mignon_drc1_3
# 82 Schumann_Mignon_drc1_2
# 82 Schumann_Mignon_drc1_1
# 83 ClaraBerryAndWooldog_AirTraffic_drc1_0
# 83 ClaraBerryAndWooldog_AirTraffic_drc1_2
# 83 ClaraBerryAndWooldog_AirTraffic_drc1_1
# 83 ClaraBerryAndWooldog_AirTraffic_drc1_3
# 84 Mozart_BesterJungling_drc1_0
# 84 Mozart_BesterJungling_drc1_2
# 84 Mozart_BesterJungling_drc1_1
# 84 Mozart_BesterJungling_drc1_3
# 85 SweetLights_YouLetMeDown_drc1_2
# 85 SweetLights_YouLetMeDown_drc1_1
# 85 SweetLights_YouLetMeDown_drc1_0
# 85 SweetLights_YouLetMeDown_drc1_3
# 86 StrandOfOaks_Spacestation_drc1_2
# 86 StrandOfOaks_Spacestation_drc1_0
# 86 StrandOfOaks_Spacestation_drc1_1
# 86 StrandOfOaks_Spacestation_drc1_3
# 87 MatthewEntwistle_TheFlaxenField_drc1_1
# 87 MatthewEntwistle_TheFlaxenField_drc1_2
# 87 MatthewEntwistle_TheFlaxenField_drc1_0
# 87 MatthewEntwistle_TheFlaxenField_drc1_3
# 88 Grants_PunchDrunk_drc1_0
# 88 Grants_PunchDrunk_drc1_3
# 88 Grants_PunchDrunk_drc1_1
# 88 Grants_PunchDrunk_drc1_2
# 89 JoelHelander_Definition_drc1_1
# 89 JoelHelander_Definition_drc1_0
# 89 JoelHelander_Definition_drc1_2
# 89 JoelHelander_Definition_drc1_3
# 90 BigTroubles_Phantom_drc1_3
# 90 BigTroubles_Phantom_drc1_2
# 90 BigTroubles_Phantom_drc1_0
# 90 BigTroubles_Phantom_drc1_1
# 91 ClaraBerryAndWooldog_Stella_drc1_2
# 91 ClaraBerryAndWooldog_Stella_drc1_0
# 91 ClaraBerryAndWooldog_Stella_drc1_1
# 91 ClaraBerryAndWooldog_Stella_drc1_3
# 92 DreamersOfTheGhetto_HeavyLove_drc1_1
# 92 DreamersOfTheGhetto_HeavyLove_drc1_3
# 92 DreamersOfTheGhetto_HeavyLove_drc1_2
# 92 DreamersOfTheGhetto_HeavyLove_drc1_0
# 93 MichaelKropf_AllGoodThings_drc1_3
# 93 MichaelKropf_AllGoodThings_drc1_0
# 93 MichaelKropf_AllGoodThings_drc1_1
# 93 MichaelKropf_AllGoodThings_drc1_2
# 94 Snowmine_Curfews_drc1_1
# 94 Snowmine_Curfews_drc1_0
# 94 Snowmine_Curfews_drc1_3
# 94 Snowmine_Curfews_drc1_2
# 95 CroqueMadame_Pilot_drc1_0
# 95 CroqueMadame_Pilot_drc1_2
# 95 CroqueMadame_Pilot_drc1_3
# 95 CroqueMadame_Pilot_drc1_1
# 96 JoelHelander_IntheAtticBedroom_drc1_1
# 96 JoelHelander_IntheAtticBedroom_drc1_2
# 96 JoelHelander_IntheAtticBedroom_drc1_3
# 96 JoelHelander_IntheAtticBedroom_drc1_0
# 97 EthanHein_BluesForNofi_drc1_1
# 97 EthanHein_BluesForNofi_drc1_0
# 97 EthanHein_BluesForNofi_drc1_3
# 97 EthanHein_BluesForNofi_drc1_2
# 98 MusicDelta_CoolJazz_drc1_0
# 98 MusicDelta_CoolJazz_drc1_2
# 98 MusicDelta_CoolJazz_drc1_3
# 98 MusicDelta_CoolJazz_drc1_1
# 99 Meaxic_YouListen_drc1_1
# 99 Meaxic_YouListen_drc1_2
# 99 Meaxic_YouListen_drc1_0
# 99 Meaxic_YouListen_drc1_3
# 100 Schubert_Erstarrung_drc1_3
# 100 Schubert_Erstarrung_drc1_0
# 100 Schubert_Erstarrung_drc1_2
# 100 Schubert_Erstarrung_drc1_1
# 101 FacesOnFilm_WaitingForGa_drc1_1
# 101 FacesOnFilm_WaitingForGa_drc1_0
# 101 FacesOnFilm_WaitingForGa_drc1_2
# 101 FacesOnFilm_WaitingForGa_drc1_3
# 102 SecretMountains_HighHorse_drc1_1
# 102 SecretMountains_HighHorse_drc1_3
# 102 SecretMountains_HighHorse_drc1_0
# 102 SecretMountains_HighHorse_drc1_2
# 103 MatthewEntwistle_ImpressionsOfSaturn_drc1_3
# 103 MatthewEntwistle_ImpressionsOfSaturn_drc1_1
# 103 MatthewEntwistle_ImpressionsOfSaturn_drc1_0
# 103 MatthewEntwistle_ImpressionsOfSaturn_drc1_2
# 104 MusicDelta_LatinJazz_drc1_3
# 104 MusicDelta_LatinJazz_drc1_2
# 104 MusicDelta_LatinJazz_drc1_0
# 104 MusicDelta_LatinJazz_drc1_1
# 105 TablaBreakbeatScience_Vger_drc1_1
# 105 TablaBreakbeatScience_Vger_drc1_2
# 105 TablaBreakbeatScience_Vger_drc1_0
# 105 TablaBreakbeatScience_Vger_drc1_3
# 106 BrandonWebster_YesSirICanFly_drc1_1
# 106 BrandonWebster_YesSirICanFly_drc1_0
# 106 BrandonWebster_YesSirICanFly_drc1_3
# 106 BrandonWebster_YesSirICanFly_drc1_2
# 107 CelestialShore_DieForUs_drc1_3
# 107 CelestialShore_DieForUs_drc1_2
# 107 CelestialShore_DieForUs_drc1_1
# 107 CelestialShore_DieForUs_drc1_0
# 108 BrandonWebster_DontHearAThing_drc1_2
# 108 BrandonWebster_DontHearAThing_drc1_3
# 108 BrandonWebster_DontHearAThing_drc1_0
# 108 BrandonWebster_DontHearAThing_drc1_1
# 109 FamilyBand_Again_drc1_3
# 109 FamilyBand_Again_drc1_2
# 109 FamilyBand_Again_drc1_1
# 109 FamilyBand_Again_drc1_0
# 110 MusicDelta_FusionJazz_drc1_1
# 110 MusicDelta_FusionJazz_drc1_2
# 110 MusicDelta_FusionJazz_drc1_3
# 110 MusicDelta_FusionJazz_drc1_0
# 111 PortStWillow_StayEven_drc1_0
# 111 PortStWillow_StayEven_drc1_3
# 111 PortStWillow_StayEven_drc1_1
# 111 PortStWillow_StayEven_drc1_2
# 112 Meaxic_TakeAStep_drc1_3
# 112 Meaxic_TakeAStep_drc1_0
# 112 Meaxic_TakeAStep_drc1_1
# 112 Meaxic_TakeAStep_drc1_2
# 113 MusicDelta_Pachelbel_drc1_1
# 113 MusicDelta_Pachelbel_drc1_3
# 113 MusicDelta_Pachelbel_drc1_0
# 113 MusicDelta_Pachelbel_drc1_2
# 114 MusicDelta_ChineseJiangNan_drc1_1
# 114 MusicDelta_ChineseJiangNan_drc1_3
# 114 MusicDelta_ChineseJiangNan_drc1_0
# 114 MusicDelta_ChineseJiangNan_drc1_2
# 115 MusicDelta_Gospel_drc1_1
# 115 MusicDelta_Gospel_drc1_0
# 115 MusicDelta_Gospel_drc1_3
# 115 MusicDelta_Gospel_drc1_2
# 116 TablaBreakbeatScience_Scorpio_drc1_3
# 116 TablaBreakbeatScience_Scorpio_drc1_2
# 116 TablaBreakbeatScience_Scorpio_drc1_1
# 116 TablaBreakbeatScience_Scorpio_drc1_0
# 117 AlexanderRoss_GoodbyeBolero_drc1_3
# 117 AlexanderRoss_GoodbyeBolero_drc1_1
# 117 AlexanderRoss_GoodbyeBolero_drc1_0
# 117 AlexanderRoss_GoodbyeBolero_drc1_2
# 118 MusicDelta_BebopJazz_drc1_3
# 118 MusicDelta_BebopJazz_drc1_2
# 118 MusicDelta_BebopJazz_drc1_0
# 118 MusicDelta_BebopJazz_drc1_1
# 119 LizNelson_Rainfall_drc1_0
# 119 LizNelson_Rainfall_drc1_2
# 119 LizNelson_Rainfall_drc1_3
# 119 LizNelson_Rainfall_drc1_1
# 120 Auctioneer_OurFutureFaces_drc1_3
# 120 Auctioneer_OurFutureFaces_drc1_1
# 120 Auctioneer_OurFutureFaces_drc1_2
# 120 Auctioneer_OurFutureFaces_drc1_0
# 121 LizNelson_ImComingHome_drc1_2
# 121 LizNelson_ImComingHome_drc1_1
# 121 LizNelson_ImComingHome_drc1_0
# 121 LizNelson_ImComingHome_drc1_3
