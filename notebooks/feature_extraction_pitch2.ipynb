# %%
import librosa
import os
import gzip
import numpy as np
from subprocess import call
import medleydb as mdb
import glob
import time

import scipy
from scipy import interpolate
print('librosa version: {:s}'.format(librosa.__version__))
print('scipy version: {:s}'.format(scipy.__version__))
print('numpy version: {:s}'.format(np.__version__))
# Out:
# librosa version: 0.5.0
# scipy version: 0.18.1
# numpy version: 1.11.3

# %%
vocalSet = set(['female singer', 'male rapper', 'male singer', 'male speaker', 'vocalists'])

# %%
# CQT Parameters
params_CQT = {
    'sr':44100, 
    'hop_length':1024, 
    'fmin':None, #Minimum frequency. Defaults to C1 ~= 32.70 Hz
    'n_bins':288, 
    'bins_per_octave':36, 
    'tuning':None, #Tuning offset in fractions of a bin (cents).
    'filter_scale':1, #Filter scale factor. Small values (<1) use shorter windows for improved time resolution.
    'norm':1, #Type of norm to use for basis function normalization.
    'sparsity':0.01, #Sparsify the CQT basis by discarding up to sparsity fraction of the energy in each basis.
    }

# %%
mdb.AUDIO_PATH
# Out:
# '/scratch/js7561/datasets/MedleyDB/Audio'

# %%
# parameters
deformer = 'pitch2'
audio_folder = '/scratch/js7561/datasets/MedleyDB_output/{:s}/audio/'.format(deformer)
output_folder = '/scratch/js7561/datasets/MedleyDB_output/{:s}/features/'.format(deformer)

compute_cqt = True
compute_activation = True

assert os.path.isdir(audio_folder)
if not os.path.isdir(output_folder):
    os.mkdir(output_folder)

# multitrack generator
trackList = os.listdir(mdb.AUDIO_PATH)
mtrack_generator = mdb.load_multitracks(trackList)

counter = 0
for track in mtrack_generator:
    
    audiofiles = glob.glob(os.path.join(audio_folder, '{:s}*.wav'.format(track.track_id)))
    for audiofile in audiofiles:
        
        filename = os.path.basename(audiofile).replace('.wav', '')  # no extension
        print(counter, filename)
        
        cqtfolder = 'cqt{:d}_{:d}_{:d}_{:d}'.format(
            params_CQT['sr'], params_CQT['hop_length'], 
            params_CQT['n_bins']//params_CQT['bins_per_octave'],
            params_CQT['bins_per_octave'])
        if not os.path.isdir(os.path.join(output_folder, cqtfolder)):
            os.mkdir(os.path.join(output_folder, cqtfolder))
        cqtfilename = '{:s}_cqt.npy.gz'.format(filename)
        cqtfullpath = os.path.join(output_folder, cqtfolder, cqtfilename)

        actfolder = 'vocal_activation{:d}_{:d}'.format(params_CQT['sr'], params_CQT['hop_length'])
        if not os.path.isdir(os.path.join(output_folder, actfolder)):
            os.mkdir(os.path.join(output_folder, actfolder))
        actfilename = '{:s}_vocalactivation.npy.gz'.format(filename)
        actfullpath = os.path.join(output_folder, actfolder, actfilename)

        if compute_cqt:

            # load audio
            x, sr = librosa.load(audiofile, sr=params_CQT['sr'])

            # compute and save log-CQT
            logcqt = librosa.logamplitude(np.abs(librosa.cqt(y=x, **params_CQT)), ref=1.0)
            np.save(gzip.open(cqtfullpath, 'wb'), logcqt)
        else:
            # for activation only
            logcqt = np.load(gzip.open(cqtfullpath, 'rb'))

        # compute vocal activation curve (corrected version)
        if compute_activation:
            vocalIdx = ([(track.stems[k].stem_idx - 1) for k in track.stems.keys() if 
                         track.stems[k].instrument[0] in vocalSet])

            try:
                if len(vocalIdx) != 0:
                    stem_activations = np.array(track.stem_activations)[:, 1:]
                    time = np.array(track.stem_activations)[:, 0]
                    vocal_activation = np.max(stem_activations[:, vocalIdx], 1)

                    # interpolation function for vocal activation curve
                    # some issue with end point(off by a few ms) so fill with last value
                    f = interpolate.interp1d(time, vocal_activation, kind='linear',
                                             bounds_error=False, fill_value=vocal_activation[-1])

                    # vocal activation lables per frame
                    specLabel = [f(i * params_CQT['hop_length'] / params_CQT['sr']) for i in range(logcqt.shape[1])]
                    specLabel = np.array(specLabel)
                else:
                    specLabel = np.zeros(logcqt.shape[1])

                # save label
                np.save(gzip.open(actfullpath, 'wb'), specLabel)
            except IndexError as err:
                print('MISSING ACTIVATION: {:s}'.format(track.track_id))
                print(err)

    counter += 1
# Out:
# 0 MusicDelta_FreeJazz_pitch2_2
# 0 MusicDelta_FreeJazz_pitch2_3
# 0 MusicDelta_FreeJazz_pitch2_1
# 0 MusicDelta_FreeJazz_pitch2_0
# 1 TablaBreakbeatScience_CaptainSky_pitch2_0
# 1 TablaBreakbeatScience_CaptainSky_pitch2_3
# 1 TablaBreakbeatScience_CaptainSky_pitch2_1
# 1 TablaBreakbeatScience_CaptainSky_pitch2_2
# 2 TablaBreakbeatScience_PhaseTransition_pitch2_1
# 2 TablaBreakbeatScience_PhaseTransition_pitch2_3
# 2 TablaBreakbeatScience_PhaseTransition_pitch2_2
# 2 TablaBreakbeatScience_PhaseTransition_pitch2_0
# 3 MusicDelta_GriegTrolltog_pitch2_3
# 3 MusicDelta_GriegTrolltog_pitch2_1
# 3 MusicDelta_GriegTrolltog_pitch2_2
# 3 MusicDelta_GriegTrolltog_pitch2_0
# 4 CroqueMadame_Oil_pitch2_1
# 4 CroqueMadame_Oil_pitch2_2
# 4 CroqueMadame_Oil_pitch2_0
# 4 CroqueMadame_Oil_pitch2_3
# 5 TablaBreakbeatScience_RockSteady_pitch2_3
# 5 TablaBreakbeatScience_RockSteady_pitch2_1
# 5 TablaBreakbeatScience_RockSteady_pitch2_2
# 5 TablaBreakbeatScience_RockSteady_pitch2_0
# 6 KarimDouaidy_Yatora_pitch2_0
# 6 KarimDouaidy_Yatora_pitch2_2
# 6 KarimDouaidy_Yatora_pitch2_1
# 6 KarimDouaidy_Yatora_pitch2_3
# 7 TheDistricts_Vermont_pitch2_0
# 7 TheDistricts_Vermont_pitch2_1
# 7 TheDistricts_Vermont_pitch2_2
# 7 TheDistricts_Vermont_pitch2_3
# 8 MusicDelta_Vivaldi_pitch2_1
# 8 MusicDelta_Vivaldi_pitch2_2
# 8 MusicDelta_Vivaldi_pitch2_3
# 8 MusicDelta_Vivaldi_pitch2_0
# 9 MusicDelta_Rockabilly_pitch2_1
# 9 MusicDelta_Rockabilly_pitch2_2
# 9 MusicDelta_Rockabilly_pitch2_3
# 9 MusicDelta_Rockabilly_pitch2_0
# 10 AlexanderRoss_VelvetCurtain_pitch2_2
# 10 AlexanderRoss_VelvetCurtain_pitch2_0
# 10 AlexanderRoss_VelvetCurtain_pitch2_1
# 10 AlexanderRoss_VelvetCurtain_pitch2_3
# 11 HopAlong_SisterCities_pitch2_2
# 11 HopAlong_SisterCities_pitch2_1
# 11 HopAlong_SisterCities_pitch2_3
# 11 HopAlong_SisterCities_pitch2_0
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_pitch2_1
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_pitch2_2
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_pitch2_3
# 12 ClaraBerryAndWooldog_WaltzForMyVictims_pitch2_0
# 13 MusicDelta_Country2_pitch2_1
# 13 MusicDelta_Country2_pitch2_2
# 13 MusicDelta_Country2_pitch2_3
# 13 MusicDelta_Country2_pitch2_0
# 14 MusicDelta_Rockabilly_pitch2_1
# 14 MusicDelta_Rock_pitch2_2
# 14 MusicDelta_Rockabilly_pitch2_2
# 14 MusicDelta_Rock_pitch2_3
# 14 MusicDelta_Rockabilly_pitch2_3
# 14 MusicDelta_Rock_pitch2_1
# 14 MusicDelta_Rock_pitch2_0
# 14 MusicDelta_Rockabilly_pitch2_0
# 15 MusicDelta_Beethoven_pitch2_0
# 15 MusicDelta_Beethoven_pitch2_2
# 15 MusicDelta_Beethoven_pitch2_1
# 15 MusicDelta_Beethoven_pitch2_3
# 16 MusicDelta_ModalJazz_pitch2_2
# 16 MusicDelta_ModalJazz_pitch2_1
# 16 MusicDelta_ModalJazz_pitch2_3
# 16 MusicDelta_ModalJazz_pitch2_0
# 17 AvaLuna_Waterduct_pitch2_3
# 17 AvaLuna_Waterduct_pitch2_0
# 17 AvaLuna_Waterduct_pitch2_1
# 17 AvaLuna_Waterduct_pitch2_2
# 18 MusicDelta_Zeppelin_pitch2_0
# 18 MusicDelta_Zeppelin_pitch2_2
# 18 MusicDelta_Zeppelin_pitch2_3
# 18 MusicDelta_Zeppelin_pitch2_1
# 19 MusicDelta_SpeedMetal_pitch2_3
# 19 MusicDelta_SpeedMetal_pitch2_0
# 19 MusicDelta_SpeedMetal_pitch2_1
# 19 MusicDelta_SpeedMetal_pitch2_2
# 20 MusicDelta_InTheHalloftheMountainKing_pitch2_2
# 20 MusicDelta_InTheHalloftheMountainKing_pitch2_0
# 20 MusicDelta_InTheHalloftheMountainKing_pitch2_3
# 20 MusicDelta_InTheHalloftheMountainKing_pitch2_1
# 21 Wolf_DieBekherte_pitch2_0
# 21 Wolf_DieBekherte_pitch2_3
# 21 Wolf_DieBekherte_pitch2_1
# 21 Wolf_DieBekherte_pitch2_2
# 22 MusicDelta_ChineseChaoZhou_pitch2_3
# 22 MusicDelta_ChineseChaoZhou_pitch2_0
# 22 MusicDelta_ChineseChaoZhou_pitch2_1
# 22 MusicDelta_ChineseChaoZhou_pitch2_2
# 23 Phoenix_ColliersDaughter_pitch2_3
# 23 Phoenix_ColliersDaughter_pitch2_1
# 23 Phoenix_ColliersDaughter_pitch2_0
# 23 Phoenix_ColliersDaughter_pitch2_2
# 24 ChrisJacoby_PigsFoot_pitch2_1
# 24 ChrisJacoby_PigsFoot_pitch2_3
# 24 ChrisJacoby_PigsFoot_pitch2_2
# 24 ChrisJacoby_PigsFoot_pitch2_0
# 25 MatthewEntwistle_FairerHopes_pitch2_0
# 25 MatthewEntwistle_FairerHopes_pitch2_2
# 25 MatthewEntwistle_FairerHopes_pitch2_3
# 25 MatthewEntwistle_FairerHopes_pitch2_1
# 26 TablaBreakbeatScience_Animoog_pitch2_2
# 26 TablaBreakbeatScience_Animoog_pitch2_3
# 26 TablaBreakbeatScience_Animoog_pitch2_0
# 26 TablaBreakbeatScience_Animoog_pitch2_1
# 27 Phoenix_ElzicsFarewell_pitch2_2
# 27 Phoenix_ElzicsFarewell_pitch2_3
# 27 Phoenix_ElzicsFarewell_pitch2_0
# 27 Phoenix_ElzicsFarewell_pitch2_1
# 28 MatthewEntwistle_TheArch_pitch2_0
# 28 MatthewEntwistle_TheArch_pitch2_3
# 28 MatthewEntwistle_TheArch_pitch2_2
# 28 MatthewEntwistle_TheArch_pitch2_1
# 29 KarimDouaidy_Hopscotch_pitch2_3
# 29 KarimDouaidy_Hopscotch_pitch2_2
# 29 KarimDouaidy_Hopscotch_pitch2_0
# 29 KarimDouaidy_Hopscotch_pitch2_1
# 30 LizNelson_Coldwar_pitch2_1
# 30 LizNelson_Coldwar_pitch2_2
# 30 LizNelson_Coldwar_pitch2_0
# 30 LizNelson_Coldwar_pitch2_3
# 31 MusicDelta_Hendrix_pitch2_0
# 31 MusicDelta_Hendrix_pitch2_3
# 31 MusicDelta_Hendrix_pitch2_2
# 31 MusicDelta_Hendrix_pitch2_1
# 32 MusicDelta_Country1_pitch2_3
# 32 MusicDelta_Country1_pitch2_2
# 32 MusicDelta_Country1_pitch2_1
# 32 MusicDelta_Country1_pitch2_0
# 33 AmarLal_SpringDay1_pitch2_2
# 33 AmarLal_SpringDay1_pitch2_3
# 33 AmarLal_SpringDay1_pitch2_1
# 33 AmarLal_SpringDay1_pitch2_0
# 34 MusicDelta_Beatles_pitch2_0
# 34 MusicDelta_Beatles_pitch2_2
# 34 MusicDelta_Beatles_pitch2_1
# 34 MusicDelta_Beatles_pitch2_3
# 35 Mozart_DiesBildnis_pitch2_3
# 35 Mozart_DiesBildnis_pitch2_0
# 35 Mozart_DiesBildnis_pitch2_2
# 35 Mozart_DiesBildnis_pitch2_1
# 36 ChrisJacoby_BoothShotLincoln_pitch2_2
# 36 ChrisJacoby_BoothShotLincoln_pitch2_1
# 36 ChrisJacoby_BoothShotLincoln_pitch2_0
# 36 ChrisJacoby_BoothShotLincoln_pitch2_3
# 37 MatthewEntwistle_AnEveningWithOliver_pitch2_3
# 37 MatthewEntwistle_AnEveningWithOliver_pitch2_0
# 37 MatthewEntwistle_AnEveningWithOliver_pitch2_2
# 37 MatthewEntwistle_AnEveningWithOliver_pitch2_1
# 38 Phoenix_SeanCaughlinsTheScartaglen_pitch2_3
# 38 Phoenix_SeanCaughlinsTheScartaglen_pitch2_1
# 38 Phoenix_SeanCaughlinsTheScartaglen_pitch2_0
# 38 Phoenix_SeanCaughlinsTheScartaglen_pitch2_2
# 39 AmarLal_Rest_pitch2_1
# 39 AmarLal_Rest_pitch2_0
# 39 AmarLal_Rest_pitch2_2
# 39 AmarLal_Rest_pitch2_3
# 40 InvisibleFamiliars_DisturbingWildlife_pitch2_0
# 40 InvisibleFamiliars_DisturbingWildlife_pitch2_3
# 40 InvisibleFamiliars_DisturbingWildlife_pitch2_2
# 40 InvisibleFamiliars_DisturbingWildlife_pitch2_1
# 41 MusicDelta_FunkJazz_pitch2_0
# 41 MusicDelta_FunkJazz_pitch2_3
# 41 MusicDelta_FunkJazz_pitch2_1
# 41 MusicDelta_FunkJazz_pitch2_2
# 42 TablaBreakbeatScience_MoodyPlucks_pitch2_0
# 42 TablaBreakbeatScience_MoodyPlucks_pitch2_2
# 42 TablaBreakbeatScience_MoodyPlucks_pitch2_3
# 42 TablaBreakbeatScience_MoodyPlucks_pitch2_1
# 43 MatthewEntwistle_DontYouEver_pitch2_2
# 43 MatthewEntwistle_DontYouEver_pitch2_1
# 43 MatthewEntwistle_DontYouEver_pitch2_0
# 43 MatthewEntwistle_DontYouEver_pitch2_3
# 44 Phoenix_BrokenPledgeChicagoReel_pitch2_2
# 44 Phoenix_BrokenPledgeChicagoReel_pitch2_1
# 44 Phoenix_BrokenPledgeChicagoReel_pitch2_0
# 44 Phoenix_BrokenPledgeChicagoReel_pitch2_3
# 45 MusicDelta_SwingJazz_pitch2_1
# 45 MusicDelta_SwingJazz_pitch2_0
# 45 MusicDelta_SwingJazz_pitch2_2
# 45 MusicDelta_SwingJazz_pitch2_3
# 46 TablaBreakbeatScience_WhoIsIt_pitch2_0
# 46 TablaBreakbeatScience_WhoIsIt_pitch2_2
# 46 TablaBreakbeatScience_WhoIsIt_pitch2_3
# 46 TablaBreakbeatScience_WhoIsIt_pitch2_1
# 47 NightPanther_Fire_pitch2_2
# 47 NightPanther_Fire_pitch2_1
# 47 NightPanther_Fire_pitch2_0
# 47 NightPanther_Fire_pitch2_3
# 48 ClaraBerryAndWooldog_TheBadGuys_pitch2_1
# 48 ClaraBerryAndWooldog_TheBadGuys_pitch2_2
# 48 ClaraBerryAndWooldog_TheBadGuys_pitch2_3
# 48 ClaraBerryAndWooldog_TheBadGuys_pitch2_0
# 49 MusicDelta_Punk_pitch2_0
# 49 MusicDelta_Punk_pitch2_1
# 49 MusicDelta_Punk_pitch2_3
# 49 MusicDelta_Punk_pitch2_2
# 50 PurlingHiss_Lolita_pitch2_2
# 50 PurlingHiss_Lolita_pitch2_0
# 50 PurlingHiss_Lolita_pitch2_3
# 50 PurlingHiss_Lolita_pitch2_1
# 51 HezekiahJones_BorrowedHeart_pitch2_3
# 51 HezekiahJones_BorrowedHeart_pitch2_0
# 51 HezekiahJones_BorrowedHeart_pitch2_2
# 51 HezekiahJones_BorrowedHeart_pitch2_1
# 52 MusicDelta_Britpop_pitch2_0
# 52 MusicDelta_Britpop_pitch2_1
# 52 MusicDelta_Britpop_pitch2_3
# 52 MusicDelta_Britpop_pitch2_2
# 53 Creepoid_OldTree_pitch2_1
# 53 Creepoid_OldTree_pitch2_3
# 53 Creepoid_OldTree_pitch2_0
# 53 Creepoid_OldTree_pitch2_2
# 54 TablaBreakbeatScience_MiloVsMongo_pitch2_3
# 54 TablaBreakbeatScience_MiloVsMongo_pitch2_1
# 54 TablaBreakbeatScience_MiloVsMongo_pitch2_2
# 54 TablaBreakbeatScience_MiloVsMongo_pitch2_0
# 55 TheSoSoGlos_Emergency_pitch2_0
# 55 TheSoSoGlos_Emergency_pitch2_2
# 55 TheSoSoGlos_Emergency_pitch2_1
# 55 TheSoSoGlos_Emergency_pitch2_3
# 56 ClaraBerryAndWooldog_Boys_pitch2_0
# 56 ClaraBerryAndWooldog_Boys_pitch2_1
# 56 ClaraBerryAndWooldog_Boys_pitch2_3
# 56 ClaraBerryAndWooldog_Boys_pitch2_2
# 57 Debussy_LenfantProdigue_pitch2_3
# 57 Debussy_LenfantProdigue_pitch2_2
# 57 Debussy_LenfantProdigue_pitch2_0
# 57 Debussy_LenfantProdigue_pitch2_1
# 58 AimeeNorwich_Flying_pitch2_0
# 58 AimeeNorwich_Flying_pitch2_3
# 58 AimeeNorwich_Flying_pitch2_2
# 58 AimeeNorwich_Flying_pitch2_1
# 59 TheScarletBrand_LesFleursDuMal_pitch2_0
# 59 TheScarletBrand_LesFleursDuMal_pitch2_3
# 59 TheScarletBrand_LesFleursDuMal_pitch2_1
# 59 TheScarletBrand_LesFleursDuMal_pitch2_2
# 60 MusicDelta_ChineseHenan_pitch2_2
# 60 MusicDelta_ChineseHenan_pitch2_3
# 60 MusicDelta_ChineseHenan_pitch2_1
# 60 MusicDelta_ChineseHenan_pitch2_0
# 61 MusicDelta_Grunge_pitch2_0
# 61 MusicDelta_Grunge_pitch2_2
# 61 MusicDelta_Grunge_pitch2_3
# 61 MusicDelta_Grunge_pitch2_1
# 62 JoelHelander_ExcessiveResistancetoChange_pitch2_2
# 62 JoelHelander_ExcessiveResistancetoChange_pitch2_3
# 62 JoelHelander_ExcessiveResistancetoChange_pitch2_0
# 62 JoelHelander_ExcessiveResistancetoChange_pitch2_1
# 63 MusicDelta_Reggae_pitch2_1
# 63 MusicDelta_Reggae_pitch2_2
# 63 MusicDelta_Reggae_pitch2_0
# 63 MusicDelta_Reggae_pitch2_3
# 64 AimeeNorwich_Child_pitch2_2
# 64 AimeeNorwich_Child_pitch2_3
# 64 AimeeNorwich_Child_pitch2_1
# 64 AimeeNorwich_Child_pitch2_0
# 65 Phoenix_ScotchMorris_pitch2_3
# 65 Phoenix_ScotchMorris_pitch2_2
# 65 Phoenix_ScotchMorris_pitch2_1
# 65 Phoenix_ScotchMorris_pitch2_0
# 66 EthanHein_1930sSynthAndUprightBass_pitch2_2
# 66 EthanHein_1930sSynthAndUprightBass_pitch2_0
# 66 EthanHein_1930sSynthAndUprightBass_pitch2_3
# 66 EthanHein_1930sSynthAndUprightBass_pitch2_1
# 67 MusicDelta_ChineseXinJing_pitch2_1
# 67 MusicDelta_ChineseXinJing_pitch2_2
# 67 MusicDelta_ChineseXinJing_pitch2_0
# 67 MusicDelta_ChineseXinJing_pitch2_3
# 68 Phoenix_LarkOnTheStrandDrummondCastle_pitch2_0
# 68 Phoenix_LarkOnTheStrandDrummondCastle_pitch2_2
# 68 Phoenix_LarkOnTheStrandDrummondCastle_pitch2_3
# 68 Phoenix_LarkOnTheStrandDrummondCastle_pitch2_1
# 69 StevenClark_Bounty_pitch2_2
# 69 StevenClark_Bounty_pitch2_1
# 69 StevenClark_Bounty_pitch2_0
# 69 StevenClark_Bounty_pitch2_3
# 70 EthanHein_HarmonicaFigure_pitch2_3
# 70 EthanHein_HarmonicaFigure_pitch2_2
# 70 EthanHein_HarmonicaFigure_pitch2_1
# 70 EthanHein_HarmonicaFigure_pitch2_0
# 71 AClassicEducation_NightOwl_pitch2_1
# 71 AClassicEducation_NightOwl_pitch2_0
# 71 AClassicEducation_NightOwl_pitch2_2
# 71 AClassicEducation_NightOwl_pitch2_3
# 72 MusicDelta_ChineseDrama_pitch2_1
# 72 MusicDelta_ChineseDrama_pitch2_0
# 72 MusicDelta_ChineseDrama_pitch2_2
# 72 MusicDelta_ChineseDrama_pitch2_3
# 73 MatthewEntwistle_Lontano_pitch2_2
# 73 MatthewEntwistle_Lontano_pitch2_0
# 73 MatthewEntwistle_Lontano_pitch2_1
# 73 MatthewEntwistle_Lontano_pitch2_3
# 74 Handel_TornamiAVagheggiar_pitch2_1
# 74 Handel_TornamiAVagheggiar_pitch2_3
# 74 Handel_TornamiAVagheggiar_pitch2_2
# 74 Handel_TornamiAVagheggiar_pitch2_0
# 75 MusicDelta_Shadows_pitch2_3
# 75 MusicDelta_Shadows_pitch2_2
# 75 MusicDelta_Shadows_pitch2_0
# 75 MusicDelta_Shadows_pitch2_1
# 76 EthanHein_GirlOnABridge_pitch2_3
# 76 EthanHein_GirlOnABridge_pitch2_2
# 76 EthanHein_GirlOnABridge_pitch2_1
# 76 EthanHein_GirlOnABridge_pitch2_0
# 77 MusicDelta_ChineseYaoZu_pitch2_0
# 77 MusicDelta_ChineseYaoZu_pitch2_1
# 77 MusicDelta_ChineseYaoZu_pitch2_3
# 77 MusicDelta_ChineseYaoZu_pitch2_2
# 78 MusicDelta_80sRock_pitch2_3
# 78 MusicDelta_80sRock_pitch2_2
# 78 MusicDelta_80sRock_pitch2_1
# 78 MusicDelta_80sRock_pitch2_0
# 79 HeladoNegro_MitadDelMundo_pitch2_2
# 79 HeladoNegro_MitadDelMundo_pitch2_1
# 79 HeladoNegro_MitadDelMundo_pitch2_3
# 79 HeladoNegro_MitadDelMundo_pitch2_0
# 80 Lushlife_ToynbeeSuite_pitch2_2
# 80 Lushlife_ToynbeeSuite_pitch2_3
# 80 Lushlife_ToynbeeSuite_pitch2_1
# 80 Lushlife_ToynbeeSuite_pitch2_0
# 81 MusicDelta_Disco_pitch2_1
# 81 MusicDelta_Disco_pitch2_0
# 81 MusicDelta_Disco_pitch2_3
# 81 MusicDelta_Disco_pitch2_2
# 82 Schumann_Mignon_pitch2_0
# 82 Schumann_Mignon_pitch2_1
# 82 Schumann_Mignon_pitch2_3
# 82 Schumann_Mignon_pitch2_2
# 83 ClaraBerryAndWooldog_AirTraffic_pitch2_1
# 83 ClaraBerryAndWooldog_AirTraffic_pitch2_3
# 83 ClaraBerryAndWooldog_AirTraffic_pitch2_0
# 83 ClaraBerryAndWooldog_AirTraffic_pitch2_2
# 84 Mozart_BesterJungling_pitch2_1
# 84 Mozart_BesterJungling_pitch2_3
# 84 Mozart_BesterJungling_pitch2_0
# 84 Mozart_BesterJungling_pitch2_2
# 85 SweetLights_YouLetMeDown_pitch2_2
# 85 SweetLights_YouLetMeDown_pitch2_1
# 85 SweetLights_YouLetMeDown_pitch2_0
# 85 SweetLights_YouLetMeDown_pitch2_3
# 86 StrandOfOaks_Spacestation_pitch2_2
# 86 StrandOfOaks_Spacestation_pitch2_0
# 86 StrandOfOaks_Spacestation_pitch2_1
# 86 StrandOfOaks_Spacestation_pitch2_3
# 87 MatthewEntwistle_TheFlaxenField_pitch2_3
# 87 MatthewEntwistle_TheFlaxenField_pitch2_0
# 87 MatthewEntwistle_TheFlaxenField_pitch2_2
# 87 MatthewEntwistle_TheFlaxenField_pitch2_1
# 88 Grants_PunchDrunk_pitch2_3
# 88 Grants_PunchDrunk_pitch2_2
# 88 Grants_PunchDrunk_pitch2_0
# 88 Grants_PunchDrunk_pitch2_1
# 89 JoelHelander_Definition_pitch2_1
# 89 JoelHelander_Definition_pitch2_3
# 89 JoelHelander_Definition_pitch2_0
# 89 JoelHelander_Definition_pitch2_2
# 90 BigTroubles_Phantom_pitch2_1
# 90 BigTroubles_Phantom_pitch2_2
# 90 BigTroubles_Phantom_pitch2_0
# 90 BigTroubles_Phantom_pitch2_3
# 91 ClaraBerryAndWooldog_Stella_pitch2_0
# 91 ClaraBerryAndWooldog_Stella_pitch2_1
# 91 ClaraBerryAndWooldog_Stella_pitch2_2
# 91 ClaraBerryAndWooldog_Stella_pitch2_3
# 92 DreamersOfTheGhetto_HeavyLove_pitch2_1
# 92 DreamersOfTheGhetto_HeavyLove_pitch2_0
# 92 DreamersOfTheGhetto_HeavyLove_pitch2_2
# 92 DreamersOfTheGhetto_HeavyLove_pitch2_3
# 93 MichaelKropf_AllGoodThings_pitch2_3
# 93 MichaelKropf_AllGoodThings_pitch2_0
# 93 MichaelKropf_AllGoodThings_pitch2_2
# 93 MichaelKropf_AllGoodThings_pitch2_1
# 94 Snowmine_Curfews_pitch2_2
# 94 Snowmine_Curfews_pitch2_0
# 94 Snowmine_Curfews_pitch2_3
# 94 Snowmine_Curfews_pitch2_1
# 95 CroqueMadame_Pilot_pitch2_1
# 95 CroqueMadame_Pilot_pitch2_0
# 95 CroqueMadame_Pilot_pitch2_3
# 95 CroqueMadame_Pilot_pitch2_2
# 96 JoelHelander_IntheAtticBedroom_pitch2_2
# 96 JoelHelander_IntheAtticBedroom_pitch2_1
# 96 JoelHelander_IntheAtticBedroom_pitch2_3
# 96 JoelHelander_IntheAtticBedroom_pitch2_0
# 97 EthanHein_BluesForNofi_pitch2_2
# 97 EthanHein_BluesForNofi_pitch2_1
# 97 EthanHein_BluesForNofi_pitch2_0
# 97 EthanHein_BluesForNofi_pitch2_3
# 98 MusicDelta_CoolJazz_pitch2_1
# 98 MusicDelta_CoolJazz_pitch2_2
# 98 MusicDelta_CoolJazz_pitch2_0
# 98 MusicDelta_CoolJazz_pitch2_3
# 99 Meaxic_YouListen_pitch2_1
# 99 Meaxic_YouListen_pitch2_3
# 99 Meaxic_YouListen_pitch2_2
# 99 Meaxic_YouListen_pitch2_0
# 100 Schubert_Erstarrung_pitch2_1
# 100 Schubert_Erstarrung_pitch2_2
# 100 Schubert_Erstarrung_pitch2_0
# 100 Schubert_Erstarrung_pitch2_3
# 101 FacesOnFilm_WaitingForGa_pitch2_2
# 101 FacesOnFilm_WaitingForGa_pitch2_0
# 101 FacesOnFilm_WaitingForGa_pitch2_3
# 101 FacesOnFilm_WaitingForGa_pitch2_1
# 102 SecretMountains_HighHorse_pitch2_0
# 102 SecretMountains_HighHorse_pitch2_2
# 102 SecretMountains_HighHorse_pitch2_3
# 102 SecretMountains_HighHorse_pitch2_1
# 103 MatthewEntwistle_ImpressionsOfSaturn_pitch2_3
# 103 MatthewEntwistle_ImpressionsOfSaturn_pitch2_1
# 103 MatthewEntwistle_ImpressionsOfSaturn_pitch2_2
# 103 MatthewEntwistle_ImpressionsOfSaturn_pitch2_0
# 104 MusicDelta_LatinJazz_pitch2_3
# 104 MusicDelta_LatinJazz_pitch2_0
# 104 MusicDelta_LatinJazz_pitch2_2
# 104 MusicDelta_LatinJazz_pitch2_1
# 105 TablaBreakbeatScience_Vger_pitch2_1
# 105 TablaBreakbeatScience_Vger_pitch2_3
# 105 TablaBreakbeatScience_Vger_pitch2_0
# 105 TablaBreakbeatScience_Vger_pitch2_2
# 106 BrandonWebster_YesSirICanFly_pitch2_3
# 106 BrandonWebster_YesSirICanFly_pitch2_0
# 106 BrandonWebster_YesSirICanFly_pitch2_1
# 106 BrandonWebster_YesSirICanFly_pitch2_2
# 107 CelestialShore_DieForUs_pitch2_3
# 107 CelestialShore_DieForUs_pitch2_1
# 107 CelestialShore_DieForUs_pitch2_2
# 107 CelestialShore_DieForUs_pitch2_0
# 108 BrandonWebster_DontHearAThing_pitch2_1
# 108 BrandonWebster_DontHearAThing_pitch2_0
# 108 BrandonWebster_DontHearAThing_pitch2_3
# 108 BrandonWebster_DontHearAThing_pitch2_2
# 109 FamilyBand_Again_pitch2_3
# 109 FamilyBand_Again_pitch2_0
# 109 FamilyBand_Again_pitch2_1
# 109 FamilyBand_Again_pitch2_2
# 110 MusicDelta_FusionJazz_pitch2_1
# 110 MusicDelta_FusionJazz_pitch2_2
# 110 MusicDelta_FusionJazz_pitch2_3
# 110 MusicDelta_FusionJazz_pitch2_0
# 111 PortStWillow_StayEven_pitch2_3
# 111 PortStWillow_StayEven_pitch2_1
# 111 PortStWillow_StayEven_pitch2_0
# 111 PortStWillow_StayEven_pitch2_2
# 112 Meaxic_TakeAStep_pitch2_2
# 112 Meaxic_TakeAStep_pitch2_1
# 112 Meaxic_TakeAStep_pitch2_3
# 112 Meaxic_TakeAStep_pitch2_0
# 113 MusicDelta_Pachelbel_pitch2_1
# 113 MusicDelta_Pachelbel_pitch2_3
# 113 MusicDelta_Pachelbel_pitch2_0
# 113 MusicDelta_Pachelbel_pitch2_2
# 114 MusicDelta_ChineseJiangNan_pitch2_0
# 114 MusicDelta_ChineseJiangNan_pitch2_1
# 114 MusicDelta_ChineseJiangNan_pitch2_2
# 114 MusicDelta_ChineseJiangNan_pitch2_3
# 115 MusicDelta_Gospel_pitch2_2
# 115 MusicDelta_Gospel_pitch2_3
# 115 MusicDelta_Gospel_pitch2_0
# 115 MusicDelta_Gospel_pitch2_1
# 116 TablaBreakbeatScience_Scorpio_pitch2_0
# 116 TablaBreakbeatScience_Scorpio_pitch2_3
# 116 TablaBreakbeatScience_Scorpio_pitch2_2
# 116 TablaBreakbeatScience_Scorpio_pitch2_1
# 117 AlexanderRoss_GoodbyeBolero_pitch2_2
# 117 AlexanderRoss_GoodbyeBolero_pitch2_1
# 117 AlexanderRoss_GoodbyeBolero_pitch2_3
# 117 AlexanderRoss_GoodbyeBolero_pitch2_0
# 118 MusicDelta_BebopJazz_pitch2_0
# 118 MusicDelta_BebopJazz_pitch2_2
# 118 MusicDelta_BebopJazz_pitch2_3
# 118 MusicDelta_BebopJazz_pitch2_1
# 119 LizNelson_Rainfall_pitch2_1
# 119 LizNelson_Rainfall_pitch2_2
# 119 LizNelson_Rainfall_pitch2_3
# 119 LizNelson_Rainfall_pitch2_0
# 120 Auctioneer_OurFutureFaces_pitch2_0
# 120 Auctioneer_OurFutureFaces_pitch2_1
# 120 Auctioneer_OurFutureFaces_pitch2_3
# 120 Auctioneer_OurFutureFaces_pitch2_2
# 121 LizNelson_ImComingHome_pitch2_2
# 121 LizNelson_ImComingHome_pitch2_0
# 121 LizNelson_ImComingHome_pitch2_3
# 121 LizNelson_ImComingHome_pitch2_1
